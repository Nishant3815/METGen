# %%
# %cd /content/drive/MyDrive/685/Project/
# !unzip emogen.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: root/ParlAI/emogen/train/images/702e1575a8eaac2ed897d89b676da46.jpg
#   inflating: root/ParlAI/emogen/train/images/ce35049cefaf192cf3fda04c1e9c8b.jpg
#   inflating: root/ParlAI/emogen/train/images/7feffea21a2213fe1f66919da55391a5.jpg
#   inflating: root/ParlAI/emogen/train/images/b8e5d2d9a4d74c342767713ab17f76e.jpg
#   inflating: root/ParlAI/emogen/train/images/eb8ba5bd4eae45d22fdfd0cac163ae88.jpg
#   inflating: root/ParlAI/emogen/train/images/70bd1acb231ff7c619dd45b345d79cd3.jpg
#   inflating: root/ParlAI/emogen/train/images/efc32b4f136e58ba271d5865b0a64a.jpg
#   inflating: root/ParlAI/emogen/train/images/26978f9a87b47847555f3c5a9228d8cc.jpg
#   inflating: root/ParlAI/emogen/train/images/b1a2e2ce72e275329985263f91d6980.jpg
#   inflating: root/ParlAI/emogen/train/images/5928d82faf648c457d824b810dfce86.jpg
#   inflating: root/ParlAI/emogen/train/images/8ae6672d98e2b484e96241a7d89a1.jpg
#   inflating: root/ParlAI/emogen/train/images/8837c37ea662e9cf7c8e9ab4c812283a.jpg
#   inflating: root/ParlAI/emogen/train/images/e8504280ff69ea9fe861f1da63c77ec0.jpg
#   inflating: root/ParlAI/emogen/train/images/664514ca956b6b4617735aa24f4fee6.jpg
#   inflating: root/ParlAI/emogen/train/images/4c383c2ac2a17082ec4d216e88f44.jpg
#   inflating: root/ParlAI/emogen/train/images/ca58d1e4e21598c23b7610c5779f2dac.jpg
#   inflating: root/ParlAI/emogen/train/images/d059947c8ae5f4b8cf13456fd4b0d918.jpg
#   inflating: root/ParlAI/emogen/train/images/48d3ef109ce65129a1b5a4c70e96b21.jpg
#   inflating: root/ParlAI/emogen/train/images/3f445ca5b50cfb7f3367af3b254a91.jpg
#   inflating: root/ParlAI/emogen/train/images/8bbd75d7bd70e11f5c6c8ab1b570fd4.jpg
#   inflating: root/ParlAI/emogen/train/images/5419e39583ca75c12571e8b62677818.jpg
#   inflating: root/ParlAI/emogen/train/images/331ec3735474049419037fdfc722a76.jpg
#   inflating: root/ParlAI/emogen/train/images/1a7fcb9957c661b06c2d859447b1ef1c.jpg
#   inflating: root/ParlAI/emogen/train/images/64f8829e16a2e1c935a978becc1e40b.jpg
#   inflating: root/ParlAI/emogen/train/images/677d61b2e438b552dd5f8c5134383b37.jpg
#   inflating: root/ParlAI/emogen/train/images/af5a5a3f27c98272f828e8dc9ccef5.jpg
#   inflating: root/ParlAI/emogen/train/images/aca591c739884677422f281c16f2edd.jpg
#   inflating: root/ParlAI/emogen/train/images/f4dc67dcb5be9548bd9af3f288d750.jpg
#   inflating: root/ParlAI/emogen/train/images/ceaf3e3dac5f5a36fa996438e798d9.jpg
#   inflating: root/ParlAI/emogen/train/images/79c5bdd08b43511347b2649dc346cfb.jpg
#   inflating: root/ParlAI/emogen/train/images/a0aff249934fbaa96d795494688b23e.jpg
#   inflating: root/ParlAI/emogen/train/images/45297a507bff99475bbac889828120.jpg
#   inflating: root/ParlAI/emogen/train/images/3ec755afc57643fe89f2fdfafb092aa.jpg
#   inflating: root/ParlAI/emogen/train/images/8fe0e3f9f560ffca71b829281248ba14.jpg
#   inflating: root/ParlAI/emogen/train/images/25e1ebdf6a28c87b9218c43e8b44194.jpg
#   inflating: root/ParlAI/emogen/train/images/2ae7a55f6e11ba2e98fb52473a687df.jpg
#   inflating: root/ParlAI/emogen/train/images/65a2bcd9c983211573974aee8f8eb071.jpg
#   inflating: root/ParlAI/emogen/train/images/c8f597c2f12d4814ab8f1681e12c79.jpg
#   inflating: root/ParlAI/emogen/train/images/cf5f45e85b69cb1bdbeabb9e89ad2482.jpg
#   inflating: root/ParlAI/emogen/train/images/218167169e41f46326c9e53865d5ea9.jpg
#   inflating: root/ParlAI/emogen/train/images/7b366cb2c0a758d2d58ccb8a49a3a688.jpg
#   inflating: root/ParlAI/emogen/train/images/2f445feeaac7fbbb88dc69b8a73d20a2.jpg
#   inflating: root/ParlAI/emogen/train/images/807b1a6c82e81ffe57803c505306dc5.jpg
#   inflating: root/ParlAI/emogen/train/images/d5781dc92f4fa510cfefd08082e9daa4.jpg
#   inflating: root/ParlAI/emogen/train/images/b643d0b02a5cd6fde980bfdd7941fc9.jpg
#   inflating: root/ParlAI/emogen/train/images/f6887bf49b2886fbc51513c702f1c.jpg
#   inflating: root/ParlAI/emogen/train/images/3ae8d47b328944a98174ac3584cf31ca.jpg
#   inflating: root/ParlAI/emogen/train/images/713958729ba1dea3c018815eaa5590c9.jpg
#   inflating: root/ParlAI/emogen/train/images/cddbcd88932de7e98757841995ab5116.jpg
#   inflating: root/ParlAI/emogen/train/images/4817f45de1c8f626a8358e62f089a2ab.jpg
#   inflating: root/ParlAI/emogen/train/images/a01d96bf0b41ad91353f0534d1c45.jpg
#   inflating: root/ParlAI/emogen/train/images/af41696543d0f3eb587d2ed23dd77.jpg
#   inflating: root/ParlAI/emogen/train/images/49189de48598d664b3147180fbcd0.jpg
#   inflating: root/ParlAI/emogen/train/images/41b71ba1c6edc9d3c66546b2daef48ad.jpg
#   inflating: root/ParlAI/emogen/train/images/975c337a38899cc2b9c8d1cd1068f93.jpg
#   inflating: root/ParlAI/emogen/train/images/d53ecfcb8b7715451b568e9d18933d.jpg
#   inflating: root/ParlAI/emogen/train/images/fe2776baebfc187ec06677be8caca545.jpg
#   inflating: root/ParlAI/emogen/train/images/aa40c2ddb162e5f989ced3631dadb2d.jpg
#   inflating: root/ParlAI/emogen/train/images/229b6e3ba6bf922e94c569824b376ec0.jpg
#   inflating: root/ParlAI/emogen/train/images/a49569aef18652b030614db86595457f.jpg
#   inflating: root/ParlAI/emogen/train/images/fcdfb1a15eebbbd65d6baee1f721dbbd.jpg
#   inflating: root/ParlAI/emogen/train/images/6612f153b063d261d2fb06aac28e081.jpg
#   inflating: root/ParlAI/emogen/train/images/e7b8e525d9f1da74e892d1ad324c28fa.jpg
#   inflating: root/ParlAI/emogen/train/images/7cf9980468aa88b5ddc38d8d6deaa.jpg
#   inflating: root/ParlAI/emogen/train/images/4819d6fa9c2e3a6add6289f12d12bd2c.jpg
#   inflating: root/ParlAI/emogen/train/images/ece7c548644961622f638cff0819b1d.jpg
#   inflating: root/ParlAI/emogen/train/images/233d1c2e3f6162e8261232d651b104e.jpg
#   inflating: root/ParlAI/emogen/train/images/3b83dc4c8432b24ecb4c90b08f357da.jpg
#   inflating: root/ParlAI/emogen/train/images/23f035e75e8126e2f7ac141794ce8d4.jpg
#   inflating: root/ParlAI/emogen/train/images/5d176e798888a2e90cf6bb55bffe29a.jpg
#   inflating: root/ParlAI/emogen/train/images/9dc3456a75fbe355b032c992face91a.jpg
#   inflating: root/ParlAI/emogen/train/images/f487da784cdc346343e2805323797d.jpg
#   inflating: root/ParlAI/emogen/train/images/5cefe2a93f834fc23c87bf4ce84f77.jpg
#   inflating: root/ParlAI/emogen/train/images/2a2124f48520b7ff18e41eadb0a9d49.jpg
#   inflating: root/ParlAI/emogen/train/images/e9e0624115cb98dafefd547546a2647a.jpg
#   inflating: root/ParlAI/emogen/train/images/bbadf6dd2f4fe8ce3d152fc34b5b742.jpg
#   inflating: root/ParlAI/emogen/train/images/4ef8185a93707ee26047c3b8e8413b86.jpg
#   inflating: root/ParlAI/emogen/train/images/94dddcb97b389bab56702dd883d5e62.jpg
#   inflating: root/ParlAI/emogen/train/images/a85be3b58b1f8daa45a7b32e645ac.jpg
#   inflating: root/ParlAI/emogen/train/images/879a37667bbebbbd442fc71a03f31f4.jpg
#   inflating: root/ParlAI/emogen/train/images/571b3c365e0cd245850cea745ed62a3.jpg
#   inflating: root/ParlAI/emogen/train/images/471264696ee454943fa4b9eb274594d.jpg
#   inflating: root/ParlAI/emogen/train/images/d6f022ca938c6331e0228962bc80d7d6.jpg
#   inflating: root/ParlAI/emogen/train/images/cade4f1b2a871edaceaa0ab3686bd2f.jpg
#   inflating: root/ParlAI/emogen/train/images/8a6c8a7f17de7fdef94f16d1f559c11.jpg
#   inflating: root/ParlAI/emogen/train/images/c85da432f7bbdc9dd37850656fa5c285.jpg
#   inflating: root/ParlAI/emogen/train/images/e5fadf94abf248c5e4ead4e733af3882.jpg
#   inflating: root/ParlAI/emogen/train/images/0ec4abab6e2ebd8aec1807445bb5d.jpg
#   inflating: root/ParlAI/emogen/train/images/262ff02b8c225665715233cbb5934a.jpg
#   inflating: root/ParlAI/emogen/train/images/b899cd2e23a61a3a3e708e5abb8ba2d0.jpg
#   inflating: root/ParlAI/emogen/train/images/e43d682ce3ee1f689c2d84ff14cb3dc.jpg
#   inflating: root/ParlAI/emogen/train/images/1d6fb0978268bda7f2cb399cd77486d.jpg
#   inflating: root/ParlAI/emogen/train/images/ec3caac5a03d466e3e279bae319635.jpg
#   inflating: root/ParlAI/emogen/train/images/c8145cfe77fffc3935a10a740aa46db.jpg
#   inflating: root/ParlAI/emogen/train/images/57c4f76bb0fd677e14cb68fec34ed55f.jpg
#   inflating: root/ParlAI/emogen/train/images/7f8de9e261a111fffc27468b22e638f.jpg
#   inflating: root/ParlAI/emogen/train/images/24beefdd9bb4a15f8bf550395718754a.jpg
#   inflating: root/ParlAI/emogen/train/images/e4b833ef1c439bc231acc6fd3e89f6cc.jpg
#   inflating: root/ParlAI/emogen/train/images/597bf67c646471738d8d6ab2a14cd7.jpg
#   inflating: root/ParlAI/emogen/train/images/526dbe35627f81f37a73312922c9763.jpg
#   inflating: root/ParlAI/emogen/train/images/152aaaf921ab142d91cba20f8ebc334.jpg
#   inflating: root/ParlAI/emogen/train/images/79274471db46cdb9231717e63a30dec.jpg
#   inflating: root/ParlAI/emogen/train/images/15c821c8e7c411ae1b4c5e7cc1e0a763.jpg
#   inflating: root/ParlAI/emogen/train/images/669520dd97c71538ceed5167abd2321.jpg
#   inflating: root/ParlAI/emogen/train/images/14f258baf2f3748e6ccc9e599c0e310.jpg
#   inflating: root/ParlAI/emogen/train/images/aac477546fb156a93520696cf1faa6cf.jpg
#   inflating: root/ParlAI/emogen/train/images/2346c3c23c7e254fefeb657d98b549.jpg
#   inflating: root/ParlAI/emogen/train/images/346ce7e1d8a83e9188e26614d81b7dc3.jpg
#   inflating: root/ParlAI/emogen/train/images/3cd3a69c41fd2053fea09a7bf4195588.jpg
#   inflating: root/ParlAI/emogen/train/images/2252b0903a9a9e131ba5c71c4ae5a8ba.jpg
#   inflating: root/ParlAI/emogen/train/images/b9fce0b728d276a7246db3b8c446d36.jpg
#   inflating: root/ParlAI/emogen/train/images/94f677a4f3e748519845d078947bbd1a.jpg
#   inflating: root/ParlAI/emogen/train/images/9ca468d4f289df2cb1b0cb63c4855847.jpg
#   inflating: root/ParlAI/emogen/train/images/1824386b8b565455b7d0f824291cda32.jpg
#   inflating: root/ParlAI/emogen/train/images/7b2697bda69fc4585a887c0675b4e5.jpg
#   inflating: root/ParlAI/emogen/train/images/48f382a85571592943884616cd9a0a1.jpg
#   inflating: root/ParlAI/emogen/train/images/d91a8f3c31c49dff17cb6da8954e61a.jpg
#   inflating: root/ParlAI/emogen/train/images/5b4adbcf69cad29a8cdedb6d846d1fb.jpg
#   inflating: root/ParlAI/emogen/train/images/30552a5abfca81ea76cb31411fb94.jpg
#   inflating: root/ParlAI/emogen/train/images/9418ef9b786419afd647857cb6ea67.jpg
#   inflating: root/ParlAI/emogen/train/images/adbc656091848719ad6ce3af9e4cb38.jpg
#   inflating: root/ParlAI/emogen/train/images/ce38d022c4bf7f617016465fcabbd2a1.jpg
#   inflating: root/ParlAI/emogen/train/images/86c31d586e29151e4cc3be439c80f558.jpg
#   inflating: root/ParlAI/emogen/train/images/b8d8508d9d599126c234babc95efbd0.jpg
#   inflating: root/ParlAI/emogen/train/images/a9a1d67d5a73daca1f415466fb24d5.jpg
#   inflating: root/ParlAI/emogen/train/images/7ad4cf63d1536c4c4d24dbea633bc9a5.jpg
#   inflating: root/ParlAI/emogen/train/images/5bdaaec0ae9cad088acbee03451a30.jpg
#   inflating: root/ParlAI/emogen/train/images/2ab89cf556a0da94e0ffec2d75d4.jpg
#   inflating: root/ParlAI/emogen/train/images/2245ca6ff9298e0f5166163cc43322.jpg
#   inflating: root/ParlAI/emogen/train/images/896ae3a5c018564beab7d46c2a1209e.jpg
#   inflating: root/ParlAI/emogen/train/images/334a4b5404956f68503621a5851a22.jpg
#   inflating: root/ParlAI/emogen/train/images/ac3a7789335b1f45b961c6fa97adef6.jpg
#   inflating: root/ParlAI/emogen/train/images/894261d778f1e31aa6018a4e23f802e.jpg
#   inflating: root/ParlAI/emogen/train/images/f4c89ce8642d5d2373912df887445128.jpg
#   inflating: root/ParlAI/emogen/train/images/3296665c6be1ed71e0b5763ce1e3a1c5.jpg
#   inflating: root/ParlAI/emogen/train/images/1e1d30d92026da50368d761676f6bde.jpg
#   inflating: root/ParlAI/emogen/train/images/d84458f2f8478461c01a8bc6b8993b99.jpg
#   inflating: root/ParlAI/emogen/train/images/e2b342b2ca3366d212eb8ce468e868.jpg
#   inflating: root/ParlAI/emogen/train/images/96a88506732bcd1856274b1c2faa8e8.jpg
#   inflating: root/ParlAI/emogen/train/images/816ae7a45ad26f5a2f2074f35d60cf3e.jpg
#   inflating: root/ParlAI/emogen/train/images/63f1f74d6486f681d2309db021605d29.jpg
#   inflating: root/ParlAI/emogen/train/images/6631bb5918242dd9d02198aebff24b12.jpg
#   inflating: root/ParlAI/emogen/train/images/d899175d4ad1fa463ab81c710776d.jpg
#   inflating: root/ParlAI/emogen/train/images/273ff35f3fe440f66fba3faa79d9eb22.jpg
#   inflating: root/ParlAI/emogen/train/images/81bcaaf73f907b3cc9acfa5f626741f.jpg
#   inflating: root/ParlAI/emogen/train/images/5c23b11ea018fe399fb255427aed9a8.jpg
#   inflating: root/ParlAI/emogen/train/images/fd3ecdf956e974e4e931ce9a2a8cf7.jpg
#   inflating: root/ParlAI/emogen/train/images/899bf52494f92adb4ebda967bd7dec3.jpg
#   inflating: root/ParlAI/emogen/train/images/5ec3dbca314ca30e35098fc1a7429c4.jpg
#   inflating: root/ParlAI/emogen/train/images/ab1b137e664a1ac557867cf699252de3.jpg
#   inflating: root/ParlAI/emogen/train/images/ffe5383ea670396fffccea1b78b587b.jpg
#   inflating: root/ParlAI/emogen/train/images/3e267823727094954ec36fa57736324.jpg
#   inflating: root/ParlAI/emogen/train/images/46a0fb1335151165d9112bcf3ffbd4c.jpg
#   inflating: root/ParlAI/emogen/train/images/e82d9623becf62f147b6337ab95897c.jpg
#   inflating: root/ParlAI/emogen/train/images/fdea93df1782af80c11a32366d473d1f.jpg
#   inflating: root/ParlAI/emogen/train/images/c975b737e1cb54e49b644071e04deec9.jpg
#   inflating: root/ParlAI/emogen/train/images/5432504cbe289558786f66e84df1386b.jpg
#   inflating: root/ParlAI/emogen/train/images/53c0d3b1b3ab255f0a9b0cc4c6cc949.jpg
#   inflating: root/ParlAI/emogen/train/images/70909911bfdbcafb309c50cd179dff37.jpg
#   inflating: root/ParlAI/emogen/train/images/8853c8aea2bb94e19f30309efdf3f0.jpg
#   inflating: root/ParlAI/emogen/train/images/f3957e5c3a2a8697cca714a116ef21.jpg
#   inflating: root/ParlAI/emogen/train/images/56838f7545c5135e06cccd58af6c22c.jpg
#   inflating: root/ParlAI/emogen/train/images/f73e4d964c137774c5dda465238e3ac.jpg
#   inflating: root/ParlAI/emogen/train/images/1d93c2a49b99e919198683c46df1d6a0.jpg
#   inflating: root/ParlAI/emogen/train/images/7f4a59a2484162f152c0e18147ab48.jpg
#   inflating: root/ParlAI/emogen/train/images/5be9ff9c9f6be472ef41496dbc11af4b.jpg
#   inflating: root/ParlAI/emogen/train/images/8218c8a75323eda2a3c5d5220e99286.jpg
#   inflating: root/ParlAI/emogen/train/images/cd35b2f448cc5cf65c53aa613e317d59.jpg
#   inflating: root/ParlAI/emogen/train/images/945de3cc611bacc811f2ee8abf7d39bf.jpg
#   inflating: root/ParlAI/emogen/train/images/e28996f7e2b38ec1318c32cafccac229.jpg
#   inflating: root/ParlAI/emogen/train/images/ed6c16ad3f02dc2d852954c105449bd.jpg
#   inflating: root/ParlAI/emogen/train/images/ddab8f495b2814f57239acbefb1447.jpg
#   inflating: root/ParlAI/emogen/train/images/60216d2ba74537dd5390179d8099da74.jpg
#   inflating: root/ParlAI/emogen/train/images/a8309c9a9b768548f71d4bb0b23bb5b1.jpg
#   inflating: root/ParlAI/emogen/train/images/e4abc6c04a8673487ad5d7545f9d7b.jpg
#   inflating: root/ParlAI/emogen/train/images/aa83a9e24367ef50ac919a1e54d511a2.jpg
#   inflating: root/ParlAI/emogen/train/images/fd532b118d2ce656218b6ed0b2d57882.jpg
#   inflating: root/ParlAI/emogen/train/images/a578cf46245ef4d3ded4688613a922b9.jpg
#   inflating: root/ParlAI/emogen/train/images/29abf44d364b2b4cca1e4d40252f52.jpg
#   inflating: root/ParlAI/emogen/train/images/38cf2f4251b977d3c1541150238f38c.jpg
#   inflating: root/ParlAI/emogen/train/images/ae9e258e8b9dd38ac6ce1f725c806a35.jpg
#   inflating: root/ParlAI/emogen/train/images/da89ec1c90673a29553de8447972edf.jpg
#   inflating: root/ParlAI/emogen/train/images/d984cd16c3366d54afde10354a7d25b.jpg
#   inflating: root/ParlAI/emogen/train/images/d2432181294745e33fd8c65a1a96fd40.jpg
#   inflating: root/ParlAI/emogen/train/images/f22fee3833b6e6faaf79d83c68f7731.jpg
#   inflating: root/ParlAI/emogen/train/images/d93d5fc1d5496259fa44bd9f1de0ac26.jpg
#   inflating: root/ParlAI/emogen/train/images/f5364f2a3e82485c1b5188a27698d911.jpg
#   inflating: root/ParlAI/emogen/train/images/68bc77b9d469dd5f390a16e0d0aeab.jpg
#   inflating: root/ParlAI/emogen/train/images/73d86739dae6a2e0e1a4c8b5c1815e8d.jpg
#   inflating: root/ParlAI/emogen/train/images/e027a53610ff5a75367bb540fe3f6d6.jpg
#   inflating: root/ParlAI/emogen/train/images/f4c26ae91d2d2e1b434bf9f7f0b5fc.jpg
#   inflating: root/ParlAI/emogen/train/images/d4dfd6f59ea7a11db485ea0b79de11.jpg
#   inflating: root/ParlAI/emogen/train/images/d1f982ab23ad6547d92f938e58088ee.jpg
#   inflating: root/ParlAI/emogen/train/images/d2f9dc9f85edc868abe9cde6db37c56.jpg
#   inflating: root/ParlAI/emogen/train/images/beedeb66bd785d1c56c61397619e3571.jpg
#   inflating: root/ParlAI/emogen/train/images/2a8d82a897c53f18a60a81da2730b8.jpg
#   inflating: root/ParlAI/emogen/train/images/ecbe1f89e1df9eca029fcaed6bac33.jpg
#   inflating: root/ParlAI/emogen/train/images/68ea7f0a07ea7808d72fbe6015f4a2.jpg
#   inflating: root/ParlAI/emogen/train/images/17d44c121cf239faa312f947a42a57b5.jpg
#   inflating: root/ParlAI/emogen/train/images/2ff012c3c292ae6a39c825b42bd5cd0.jpg
#   inflating: root/ParlAI/emogen/train/images/56d127cb72b13f79b4457cbc93d7e6a6.jpg
#   inflating: root/ParlAI/emogen/train/images/88b4556126168871efa963118773375.jpg
#   inflating: root/ParlAI/emogen/train/images/47241618bc761c6d9fb7769f9e68e1a2.jpg
#   inflating: root/ParlAI/emogen/train/images/4288247ca8ebb36d459f4c12825c41.jpg
#   inflating: root/ParlAI/emogen/train/images/7a598a3d73ff2664a1de93be1a44c.jpg
#   inflating: root/ParlAI/emogen/train/images/13f739ea7e2ed4db939d83a2389f0e7.jpg
#   inflating: root/ParlAI/emogen/train/images/1c42a9809bbe987fc88f237f59223b.jpg
#   inflating: root/ParlAI/emogen/train/images/a6231dc37a4a3632b823cd78422858.jpg
#   inflating: root/ParlAI/emogen/train/images/808e4afbf5c4632c67c439a84cf3f6.jpg
#   inflating: root/ParlAI/emogen/train/images/6c7d9c4540b0aa6768993ea3f4b53.jpg
#   inflating: root/ParlAI/emogen/train/images/8e584681d61ac45d2a252ae8712b3f.jpg
#   inflating: root/ParlAI/emogen/train/images/8f4829036ffe6909620adf525a6685.jpg
#   inflating: root/ParlAI/emogen/train/images/1ec3292d893c2d7574f1b1273a65bc63.jpg
#   inflating: root/ParlAI/emogen/train/images/cddb9620a958e32f3d85d8b82ffa27.jpg
#   inflating: root/ParlAI/emogen/train/images/1f2a8d7935347323c868ca2e1d616ee.jpg
#   inflating: root/ParlAI/emogen/train/images/5df89d19c749544b5674b5e5e64ffe5.jpg
#   inflating: root/ParlAI/emogen/train/images/6a04c6bd65556a5a9e36b25215b9ad.jpg
#   inflating: root/ParlAI/emogen/train/images/d2e78c828a59576183e82fdaa540dc9b.jpg
#   inflating: root/ParlAI/emogen/train/images/cf80daedeff6af8cb36691abdcb8ec4.jpg
#   inflating: root/ParlAI/emogen/train/images/fd19a54fdf0c12b4b4c9725af7368c.jpg
#   inflating: root/ParlAI/emogen/train/images/dc2f9e1f7ba7b952758dbd6430efac.jpg
#   inflating: root/ParlAI/emogen/train/images/62c03c229f19f3a0f6b07c2a187e40dc.jpg
#   inflating: root/ParlAI/emogen/train/images/9c80389a6eaffdc843f2b90db9fb6c3.jpg
#   inflating: root/ParlAI/emogen/train/images/5f4a1852e246701de1416cbffc6a5847.jpg
#   inflating: root/ParlAI/emogen/train/images/8aa9e9d032af8d52f91b89c1288a9e57.jpg
#   inflating: root/ParlAI/emogen/train/images/7f33e9248d2430529edc3a5373de2688.jpg
#   inflating: root/ParlAI/emogen/train/images/a0e6ce842c4232e1dea958c5783de64.jpg
#   inflating: root/ParlAI/emogen/train/images/e6991a424ca012b9e7a68cec64323117.jpg
#   inflating: root/ParlAI/emogen/train/images/419fc3fd27ece683c0708b5def76771a.jpg
#   inflating: root/ParlAI/emogen/train/images/e134d6707c11f14db49e9d1b128524e5.jpg
#   inflating: root/ParlAI/emogen/train/images/fe3a6155949ba188667392fea905f81.jpg
#   inflating: root/ParlAI/emogen/train/images/5d6936f7cfe3e898c15413efa22360.jpg
#   inflating: root/ParlAI/emogen/train/images/53fbd9343e0dab3bf1e32a18a12c9d.jpg
#   inflating: root/ParlAI/emogen/train/images/a78539967c176b22126f46fb44873c4.jpg
#   inflating: root/ParlAI/emogen/train/images/3eeb835fd4cf24dbb5c671ff769fa85.jpg
#   inflating: root/ParlAI/emogen/train/images/e98048b1bc7aa84b834b24717d3afdd.jpg
#   inflating: root/ParlAI/emogen/train/images/bfb90895c841e3cd4cfd2c2a2568f62.jpg
#   inflating: root/ParlAI/emogen/train/images/40a33e5d12f61beecc8f322c664780be.jpg
#   inflating: root/ParlAI/emogen/train/images/82f7ea9c446f4de71107ad4d8264bda.jpg
#   inflating: root/ParlAI/emogen/train/images/9bb867b0a72c262e793a6c6efcf63047.jpg
#   inflating: root/ParlAI/emogen/train/images/946fc3d2120dca8338cae6c15af999c.jpg
#   inflating: root/ParlAI/emogen/train/images/1532f8e03a47a0d7feb7b7c14740b8e8.jpg
#   inflating: root/ParlAI/emogen/train/images/abdd625ec83f7fa4e0ae7b626d7816.jpg
#   inflating: root/ParlAI/emogen/train/images/3851282817b887e0ca4b942b71dd62c4.jpg
#   inflating: root/ParlAI/emogen/train/images/93cb392ad7ce38dc7bcda8cd1786d3.jpg
#   inflating: root/ParlAI/emogen/train/images/bb99759470e7a38715ecfbfd6990ad24.jpg
#   inflating: root/ParlAI/emogen/train/images/6a2dbe7da1102e30175d477366e54.jpg
#   inflating: root/ParlAI/emogen/train/images/846b0917eaa65cc9ecf881eea355.jpg
#   inflating: root/ParlAI/emogen/train/images/77e68bd4d86cc7adc8d2d8bdda5245d7.jpg
#   inflating: root/ParlAI/emogen/train/images/5ea0dda2df5e86fbae0f14612d46568.jpg
#   inflating: root/ParlAI/emogen/train/images/3a3264666479b20df1fffa4fed485a.jpg
#   inflating: root/ParlAI/emogen/train/images/d5a3888090f27f20a92713f8f78762f.jpg
#   inflating: root/ParlAI/emogen/train/images/c45ab16bc7ee269987fdfb05ebca259.jpg
#   inflating: root/ParlAI/emogen/train/images/4d662b3262ddbabb0ad9110dc65aa4.jpg
#   inflating: root/ParlAI/emogen/train/images/ee17f732ea798fcb317d3bee9a3050e.jpg
#   inflating: root/ParlAI/emogen/train/images/3cfe246693e41de47e38a056dba96410.jpg
#   inflating: root/ParlAI/emogen/train/images/54cc79226b1a9aff3bce9a659e97a32.jpg
#   inflating: root/ParlAI/emogen/train/images/95a95e43451db5e8c27815354fc72b1.jpg
#   inflating: root/ParlAI/emogen/train/images/e495bbe485d8b5acb672bea19cc357.jpg
#   inflating: root/ParlAI/emogen/train/images/da8348d691479485105d54c08825de5.jpg
#   inflating: root/ParlAI/emogen/train/images/8d22397dc0ba233c30c13c3b8fe8238e.jpg
#   inflating: root/ParlAI/emogen/train/images/d8ea74248dcfcf1b76b26bcdfc23cf9c.jpg
#   inflating: root/ParlAI/emogen/train/images/9f3f1d6ac571f51e1c94b1558c1f0db.jpg
#   inflating: root/ParlAI/emogen/train/images/be7f36244789f19b9b7229b07b49cfa.jpg
#   inflating: root/ParlAI/emogen/train/images/285a9ec6bbfd285b18dd95aece9ba3.jpg
#   inflating: root/ParlAI/emogen/train/images/2ba3b6152d45f8b5b73eaa725b1f271c.jpg
#   inflating: root/ParlAI/emogen/train/images/f7fce92b593a3f4b92c9d387be14329c.jpg
#   inflating: root/ParlAI/emogen/train/images/5de462c0637b23a35fbd923d29c23469.jpg
#   inflating: root/ParlAI/emogen/train/images/529f996f7693f28f37a45a6d86712ef.jpg
#   inflating: root/ParlAI/emogen/train/images/f7724251d632a3eb6fc7578123e4bf69.jpg
#   inflating: root/ParlAI/emogen/train/images/efd29e4857fd18ff3f6176aa4b63cea.jpg
#   inflating: root/ParlAI/emogen/train/images/ab44dab69173ac331619f9681a1ee7.jpg
#   inflating: root/ParlAI/emogen/train/images/1cbc421391176476d3c2cdd4bcd31.jpg
#   inflating: root/ParlAI/emogen/train/images/d91f3f97b75d2b03560e97a559d53f.jpg
#   inflating: root/ParlAI/emogen/train/images/ecefe8ac28f5a568c010898747207926.jpg
#   inflating: root/ParlAI/emogen/train/images/5d775127ba1b14fbb5d594defe1463.jpg
#   inflating: root/ParlAI/emogen/train/images/d0bcae9daf80c1f89b79b451f8bf7163.jpg
#   inflating: root/ParlAI/emogen/train/images/1f7165dfbed8bd7656d098e6cf9710fb.jpg
#   inflating: root/ParlAI/emogen/train/images/4ca438313e33f529eeb6c29ad24d7d8b.jpg
#   inflating: root/ParlAI/emogen/train/images/e1631612ea4a34bb59ad1e35b1e17154.jpg
#   inflating: root/ParlAI/emogen/train/images/ae1d475abddc2377151904513c80a4.jpg
#   inflating: root/ParlAI/emogen/train/images/22e1a98f8d5ec1a889e7fbe87bf15b.jpg
#   inflating: root/ParlAI/emogen/train/images/cc99d5afc08dff8852f0204f2e62bb1a.jpg
#   inflating: root/ParlAI/emogen/train/images/89a9ca5879916068f0f93232e199ce2c.jpg
#   inflating: root/ParlAI/emogen/train/images/eddfa99d9ade119aa6ed6d7b12e464.jpg
#   inflating: root/ParlAI/emogen/train/images/a4747f9fa5cebcd06c85cb4f6c4f718e.jpg
#   inflating: root/ParlAI/emogen/train/images/ef3dbf673d9f81e64bde3b734c6b2be.jpg
#   inflating: root/ParlAI/emogen/train/images/b13c5d2480a2a8f7d5f44e7619f7eb9d.jpg
#   inflating: root/ParlAI/emogen/train/images/96b1d90d30ac8d8f287bdd2b91e192.jpg
#   inflating: root/ParlAI/emogen/train/images/611c4ace3739b99253531b63e5e377f.jpg
#   inflating: root/ParlAI/emogen/train/images/66ed4c5cbf57d068923fe856602dd9bf.jpg
#   inflating: root/ParlAI/emogen/train/images/7fe4d0e955338da556fcdac46fda592.jpg
#   inflating: root/ParlAI/emogen/train/images/1d98175a9e386440c243ed7edbae17d.jpg
#   inflating: root/ParlAI/emogen/train/images/7d42a1bedad0e8c1612eb115414177.jpg
#   inflating: root/ParlAI/emogen/train/images/f0d0a464a2e158dd9591931ab04d69.jpg
#   inflating: root/ParlAI/emogen/train/images/4af9e7961219d3874cece62731c8fd3d.jpg
#   inflating: root/ParlAI/emogen/train/images/35850385a969f7856293706593eaa4.jpg
#   inflating: root/ParlAI/emogen/train/images/b29121c8ee33b1df3676f7cb9f8465.jpg
#   inflating: root/ParlAI/emogen/train/images/ba1fbfb5aefc29a1bc02e261843e98e.jpg
#   inflating: root/ParlAI/emogen/train/images/6bc1683745b3ae45acaef6c2e3b4b921.jpg
#   inflating: root/ParlAI/emogen/train/images/e5e1cee7a8e25642638eff3a1916799.jpg
#   inflating: root/ParlAI/emogen/train/images/b0b05973e353a3c3f67aab1c1196f.jpg
#   inflating: root/ParlAI/emogen/train/images/1fba8d7f0aa9770ed5eebad81ecd34c.jpg
#   inflating: root/ParlAI/emogen/train/images/3e1d32f467bd3be4f949cc62aaf4dc5.jpg
#   inflating: root/ParlAI/emogen/train/images/bde81891b1a575375296fdcc21fdeb9.jpg
#   inflating: root/ParlAI/emogen/train/images/afce2fa8bf71ae418d1813f179b97ac.jpg
#   inflating: root/ParlAI/emogen/train/images/2b5e8f3583934b3ceb7daaa96caca4a7.jpg
#   inflating: root/ParlAI/emogen/train/images/feb39cf81e53096ff659299c7943991.jpg
#   inflating: root/ParlAI/emogen/train/images/7560f2de40985162a98bd53dbd22863d.jpg
#   inflating: root/ParlAI/emogen/train/images/8279a633449265bc1d56863273a329.jpg
#   inflating: root/ParlAI/emogen/train/images/d6e95aab9066cc7acc96a11643dd8c1b.jpg
#   inflating: root/ParlAI/emogen/train/images/9726a5af36510995677a1d1fc9bebf0.jpg
#   inflating: root/ParlAI/emogen/train/images/43cb974b474c3c13be417105d62f829.jpg
#   inflating: root/ParlAI/emogen/train/images/609a2325fe67681c54c3eee59cd31f3.jpg
#   inflating: root/ParlAI/emogen/train/images/98346abae720cd5fdf5f2a889654ff95.jpg
#   inflating: root/ParlAI/emogen/train/images/5d32d7e7a4354d7edbaf919e12a12a.jpg
#   inflating: root/ParlAI/emogen/train/images/954872663dd1273a6b793e149a46edae.jpg
#   inflating: root/ParlAI/emogen/train/images/a6ad318a96856c1bab01193fe71c281.jpg
#   inflating: root/ParlAI/emogen/train/images/dcf2be2af1404dd13136a3b6ed1f240.jpg
#   inflating: root/ParlAI/emogen/train/images/bcded07eb2ec5d98b7ee6eed25bd3aa7.jpg
#   inflating: root/ParlAI/emogen/train/images/3865583cb1ed13a8fc28e7aa571ecc.jpg
#   inflating: root/ParlAI/emogen/train/images/24c7c5e239d78be75b24128bb11a51c8.jpg
#   inflating: root/ParlAI/emogen/train/images/36ddbbcd9cb3a2a3262c177b4ad24f73.jpg
#   inflating: root/ParlAI/emogen/train/images/e9a867b54d35ed9abe83525814aa2cc.jpg
#   inflating: root/ParlAI/emogen/train/images/b6c667fd2d1c61e6745d534224fabbe5.jpg
#   inflating: root/ParlAI/emogen/train/images/50c61b124f2c58ea8321bfb60182898.jpg
#   inflating: root/ParlAI/emogen/train/images/31c15991c0e6b084cec55be98614bc.jpg
#   inflating: root/ParlAI/emogen/train/images/daf5c7b75613d73b5156ddbb8d24e285.jpg
#   inflating: root/ParlAI/emogen/train/images/15861d513c67b0eeb2793ed96b1df4e0.jpg
#   inflating: root/ParlAI/emogen/train/images/458377de91229bcbe12d6ffa88a7d.jpg
#   inflating: root/ParlAI/emogen/train/images/2c7b853331f9a17a6ad1b616eb07665.jpg
#   inflating: root/ParlAI/emogen/train/images/cabaa60c3c45dd4899e636819c1a6.jpg
#   inflating: root/ParlAI/emogen/train/images/a51c2d322a3a54595df2e1db4181f.jpg
#   inflating: root/ParlAI/emogen/train/images/228cd57f26db9ed997eb292d8d3d65da.jpg
#   inflating: root/ParlAI/emogen/train/images/95aeff683d39a05e6860f3e6ac1fc01e.jpg
#   inflating: root/ParlAI/emogen/train/images/9d5480dfb5e27aba356839b62d67468.jpg
#   inflating: root/ParlAI/emogen/train/images/12228d887e31fa873d8776e5de48fc8.jpg
#   inflating: root/ParlAI/emogen/train/images/3972bcf8faa273bdaf52b8b835622.jpg
#   inflating: root/ParlAI/emogen/train/images/632dbc994350f35e69b9d8b281e036b1.jpg
#   inflating: root/ParlAI/emogen/train/images/ed4d3693979aba8fbb877d123c6c9a32.jpg
#   inflating: root/ParlAI/emogen/train/images/c1cab95c99ccd24c52ac46637fe17f.jpg
#   inflating: root/ParlAI/emogen/train/images/fce6d938e6b9374872f3e21fc12712b.jpg
#   inflating: root/ParlAI/emogen/train/images/5a73825b87d83230811a686539f716cf.jpg
#   inflating: root/ParlAI/emogen/train/images/52fe979c055fe9272e8a2e1a5aa7674.jpg
#   inflating: root/ParlAI/emogen/train/images/995de698b6af41f841c541c1b93e7.jpg
#   inflating: root/ParlAI/emogen/train/images/4ade8b8682eb0c3198d8e2308da949.jpg
#   inflating: root/ParlAI/emogen/train/images/514891e525169642de19bb7d9ce4492.jpg
#   inflating: root/ParlAI/emogen/train/images/66e962d4a9fe4eb716fe46db6e53671.jpg
#   inflating: root/ParlAI/emogen/train/images/192a98b72c8157a5ad40c092713bf8.jpg
#   inflating: root/ParlAI/emogen/train/images/a22686197f85e8668dee41e274dd.jpg
#   inflating: root/ParlAI/emogen/train/images/63c94bd3cc5bdf71fbe8c7a345999ae6.jpg
#   inflating: root/ParlAI/emogen/train/images/bf63105090bfb0144768b49741e1129a.jpg
#   inflating: root/ParlAI/emogen/train/images/90538ec3515ea1f7a3df4908dc0813.jpg
#   inflating: root/ParlAI/emogen/train/images/211583b7901e6a3b7f9a89e6b6cfabed.jpg
#   inflating: root/ParlAI/emogen/train/images/27f8313984c178942ba82aae8a8031d.jpg
#   inflating: root/ParlAI/emogen/train/images/9c763a165a1834e6b707d49f8e0662d.jpg
#   inflating: root/ParlAI/emogen/train/images/f75b17b763891cf98663a781a15ade7.jpg
#   inflating: root/ParlAI/emogen/train/images/7e4127cbd478a964eb53ea0e22d3b0.jpg
#   inflating: root/ParlAI/emogen/train/images/eba27c61f2ca2706637f134dfd9e6f.jpg
#   inflating: root/ParlAI/emogen/train/images/f9e0a2cb5f83ad121bc37bc7b4db2e.jpg
#   inflating: root/ParlAI/emogen/train/images/d415942a51c8fa9290b0612428a6e87.jpg
#   inflating: root/ParlAI/emogen/train/images/4064516795b8a75ce7a5a1b9d41af5.jpg
#   inflating: root/ParlAI/emogen/train/images/e4beb3ff817d7a57b6ffc963fcebd3f.jpg
#   inflating: root/ParlAI/emogen/train/images/f362689d496d823a69b26b4e343dc84b.jpg
#   inflating: root/ParlAI/emogen/train/images/7322febe4f5a89d7685a439de867863b.jpg
#   inflating: root/ParlAI/emogen/train/images/ae9562d6d5f4ee5629d375458cb651d.jpg
#   inflating: root/ParlAI/emogen/train/images/f65347ebaac2d6c1e941cd8bee92539.jpg
#   inflating: root/ParlAI/emogen/train/images/e2ad75d75d091144d7f585457d0f9d1.jpg
#   inflating: root/ParlAI/emogen/train/images/f5e9a438615e6bca6ebabb9f72e7f3.jpg
#   inflating: root/ParlAI/emogen/train/images/f9293f766fdc2d27201cadc633879c8.jpg
#   inflating: root/ParlAI/emogen/train/images/998e0f8226b86455aef4fc58717a4.jpg
#   inflating: root/ParlAI/emogen/train/images/8178624ed8e2af20fa2dd5b3f134727a.jpg
#   inflating: root/ParlAI/emogen/train/images/2ab0d5dfec3f874ecbc8de0908099f.jpg
#   inflating: root/ParlAI/emogen/train/images/7095437ba7efc872b2671ac4ec362024.jpg
#   inflating: root/ParlAI/emogen/train/images/a772b0eb204cd6f864a6b2603c37e659.jpg
#   inflating: root/ParlAI/emogen/train/images/ed802a0c77eeeb3ef64a8ed4fd59154.jpg
#   inflating: root/ParlAI/emogen/train/images/82e1f868bfa2ec546d262f218ce7ade.jpg
#   inflating: root/ParlAI/emogen/train/images/68978b3decff2114823a744cf4edd48.jpg
#   inflating: root/ParlAI/emogen/train/images/8b3f917874a3dd5afc257e159a13938.jpg
#   inflating: root/ParlAI/emogen/train/images/643f6480a932c132acde2230b286372.jpg
#   inflating: root/ParlAI/emogen/train/images/9de9ccc4485a32fb04b11651d3ee98.jpg
#   inflating: root/ParlAI/emogen/train/images/1be878ab748f3afcada3b06ba43c9d.jpg
#   inflating: root/ParlAI/emogen/train/images/de7bf4823e91b7fcfdd5e365df517.jpg
#   inflating: root/ParlAI/emogen/train/images/c63d8e7d99aba97ba50bd9071d1d2ef.jpg
#   inflating: root/ParlAI/emogen/train/images/3ad0d6b946cd1f7e376d191876dfa4c.jpg
#   inflating: root/ParlAI/emogen/train/images/9a16bc7f249938fb93d563f9371b9e.jpg
#   inflating: root/ParlAI/emogen/train/images/62a9d418bcbe15fad7cc88acabe62fd2.jpg
#   inflating: root/ParlAI/emogen/train/images/d651c0eefa6c98c112c5a0a518aa88b.jpg
#   inflating: root/ParlAI/emogen/train/images/f6ad76a7a4c3c33eaec9ac9179739f0.jpg
#   inflating: root/ParlAI/emogen/train/images/28ab1a85346cf6b0b6928719882549a.jpg
#   inflating: root/ParlAI/emogen/train/images/a0f6a44efc6160688b1fcaa48636e6.jpg
#   inflating: root/ParlAI/emogen/train/images/b8241c92c4904ea66c2dadc29f6843f2.jpg
#   inflating: root/ParlAI/emogen/train/images/2adee81e66f7d7b7b6c5c47875b22336.jpg
#   inflating: root/ParlAI/emogen/train/images/66341f1255ac2f21b251fdefda8d88e.jpg
#   inflating: root/ParlAI/emogen/train/images/bf328d50fadf83818f1d34364abd33c.jpg
#   inflating: root/ParlAI/emogen/train/images/734b412b17bcd14e7a8d9b425af1fe.jpg
#   inflating: root/ParlAI/emogen/train/images/ef82dd24a4bf1f25acfd3b4c2e695d.jpg
#   inflating: root/ParlAI/emogen/train/images/60e911ad476176e51efdcfa7ca5933c0.jpg
#   inflating: root/ParlAI/emogen/train/images/782766ad91d9acf8c3944ec9e36f417d.jpg
#   inflating: root/ParlAI/emogen/train/images/c4db24bf9e1e2d10c4357a999833bfcd.jpg
#   inflating: root/ParlAI/emogen/train/images/da4f95c57ed9792bc7fd7fe6822219b.jpg
#   inflating: root/ParlAI/emogen/train/images/e4ff954daa789a36c92befc7d1e756b.jpg
#   inflating: root/ParlAI/emogen/train/images/9ebcf381d2be1e99e482eadeb742532b.jpg
#   inflating: root/ParlAI/emogen/train/images/7fc54fa8cb88081923efcd42a31286b.jpg
#   inflating: root/ParlAI/emogen/train/images/3d2682ea17a0dbfe1022fc6c199083a5.jpg
#   inflating: root/ParlAI/emogen/train/images/4859aef914fd6591b9583f82e229c3af.jpg
#   inflating: root/ParlAI/emogen/train/images/b6c67deb44b732e7789a2355c115f50.jpg
#   inflating: root/ParlAI/emogen/train/images/fef594f0719d4578921243db8eb5dd34.jpg
#   inflating: root/ParlAI/emogen/train/images/3e5cc8186c25c28239f561028b489b0.jpg
#   inflating: root/ParlAI/emogen/train/images/3c9c9c55d2f1a94a83f2da12c73e5b.jpg
#   inflating: root/ParlAI/emogen/train/images/3db98eca855cd0bbb6abcbeb2426d35.jpg
#   inflating: root/ParlAI/emogen/train/images/8f8c8d16c674b0145a3d7a7758d8896.jpg
#   inflating: root/ParlAI/emogen/train/images/524b33cfbea68909e966ca28ef7943.jpg
#   inflating: root/ParlAI/emogen/train/images/4d47e573157cf6c1e49b49fc6338b3fc.jpg
#   inflating: root/ParlAI/emogen/train/images/2a7405bde68f8d5796de56ff411a8.jpg
#   inflating: root/ParlAI/emogen/train/images/96666d1ec8c7cf25c543208848cd5.jpg
#   inflating: root/ParlAI/emogen/train/images/48c5d4527e5e08cbfb99a63d410ec21.jpg
#   inflating: root/ParlAI/emogen/train/images/63f77f05a4dd7dc78f9ff4b6373ae8.jpg
#   inflating: root/ParlAI/emogen/train/images/18bff05bcc7a21fcb6c8f6f0f9e78557.jpg
#   inflating: root/ParlAI/emogen/train/images/764aa8e2ecf52b96a668d047dc50e864.jpg
#   inflating: root/ParlAI/emogen/train/images/bd929b5973898d976eabffeba18f3aa6.jpg
#   inflating: root/ParlAI/emogen/train/images/34e6e0c5242830060428ce85e32ed.jpg
#   inflating: root/ParlAI/emogen/train/images/eabadf9b78cc2c5981e43a840fd1755.jpg
#   inflating: root/ParlAI/emogen/train/images/8453aed854b33ecd34d39d7ddde62.jpg
#   inflating: root/ParlAI/emogen/train/images/780496273060295a94e33a8ada31db.jpg
#   inflating: root/ParlAI/emogen/train/images/8af6ecd25fffca1ac22c1fb452503270.jpg
#   inflating: root/ParlAI/emogen/train/images/8471961d39da6ecc7b27ca8a697063d8.jpg
#   inflating: root/ParlAI/emogen/train/images/489fe9ab3b61702e86da7e85eab3a1f2.jpg
#   inflating: root/ParlAI/emogen/train/images/dab38b93d78791535be282f3205755e6.jpg
#   inflating: root/ParlAI/emogen/train/images/f2e21f4c5937c77d9bcd4a578511bf.jpg
#   inflating: root/ParlAI/emogen/train/images/60af1cb96e7bb596af4a5bd61e67a9.jpg
#   inflating: root/ParlAI/emogen/train/images/53597f924225e4a49de65f8163cfabb.jpg
#   inflating: root/ParlAI/emogen/train/images/ba8ed2a8c412b523dc6bce7f73c28a4.jpg
#   inflating: root/ParlAI/emogen/train/images/2ff7fa66d3932f8959d2c498e80bfbc.jpg
#   inflating: root/ParlAI/emogen/train/images/f69e9e2a96a3d26d6a016bcdf5a73c.jpg
#   inflating: root/ParlAI/emogen/train/images/887834a9f65c71a274e2b58fccebb2b.jpg
#   inflating: root/ParlAI/emogen/train/images/53616786e24363c735064817142e3e2.jpg
#   inflating: root/ParlAI/emogen/train/images/d7535c9b85811df35b2745e7e5fdbab.jpg
#   inflating: root/ParlAI/emogen/train/images/de2d53130edab635340f314a9d558d5.jpg
#   inflating: root/ParlAI/emogen/train/images/7c84e6b7241ff665c91c909c5a6d519c.jpg
#   inflating: root/ParlAI/emogen/train/images/da29b93040e2eb44b821a5fa5196a09f.jpg
#   inflating: root/ParlAI/emogen/train/images/f1533474bc2729c33e13ee37a55ac042.jpg
#   inflating: root/ParlAI/emogen/train/images/fa2c29e133b1eb978b796d7a3a935ece.jpg
#   inflating: root/ParlAI/emogen/train/images/45b99038c5442dd340f263d8d4fb86e0.jpg
#   inflating: root/ParlAI/emogen/train/images/4fafeb497f7f20ca9e949f20173f65df.jpg
#   inflating: root/ParlAI/emogen/train/images/635eef7f15a2680cdb97a21182c52d.jpg
#   inflating: root/ParlAI/emogen/train/images/155e7c55a2bcf4f5426f91b11f1cf7e0.jpg
#   inflating: root/ParlAI/emogen/train/images/ce68df91b15d312362111336a8bee.jpg
#   inflating: root/ParlAI/emogen/train/images/7e4d6f2e56a19a4ec6fefc08bba48c.jpg
#   inflating: root/ParlAI/emogen/train/images/1c573bc2f2a0f8be7951f8a4165c5c6.jpg
#   inflating: root/ParlAI/emogen/train/images/b15fa23d7bded4561b7c87cadd6f57.jpg
#   inflating: root/ParlAI/emogen/train/images/5413a8a463058ff65d6b4f25dc31621.jpg
#   inflating: root/ParlAI/emogen/train/images/3d4b5d846133f8ac1d77e661291add29.jpg
#   inflating: root/ParlAI/emogen/train/images/17d74444f22c7a2f8215bc259c6eb.jpg
#   inflating: root/ParlAI/emogen/train/images/9f5fffcf549b257e335c5c2de05b7fdd.jpg
#   inflating: root/ParlAI/emogen/train/images/10b6b6e4f0e8b5e1f9fec02ec66cafb.jpg
#   inflating: root/ParlAI/emogen/train/images/16eb7d3aadb9ed845e4151bb4babd4f5.jpg
#   inflating: root/ParlAI/emogen/train/images/6beab97c5c5cc493577066f82b6f855a.jpg
#   inflating: root/ParlAI/emogen/train/images/85bb3e8fdf738ff6d3ed7e1afa15d231.jpg
#   inflating: root/ParlAI/emogen/train/images/75658291418db6b79dea90195c8a.jpg
#   inflating: root/ParlAI/emogen/train/images/f0a252672536e345529c18514dc12b.jpg
#   inflating: root/ParlAI/emogen/train/images/b252a8dfe15d4582ea5d9da5c759a47.jpg
#   inflating: root/ParlAI/emogen/train/images/a745f5254f81ffa4e85c8ee19269d8b.jpg
#   inflating: root/ParlAI/emogen/train/images/b23b1877c31f3f327a408acf10be9.jpg
#   inflating: root/ParlAI/emogen/train/images/38eb4c0576bf62d77a88dcb49526c39.jpg
#   inflating: root/ParlAI/emogen/train/images/e0dc723e404eeb35a388d64f61a041cf.jpg
#   inflating: root/ParlAI/emogen/train/images/b06b53e2b32feb10b3c1fe98e98594.jpg
#   inflating: root/ParlAI/emogen/train/images/27f7be6a09a2753f328bf6b95e449e.jpg
#   inflating: root/ParlAI/emogen/train/images/6050e23bb708267f3c8577e4d621e31.jpg
#   inflating: root/ParlAI/emogen/train/images/cd728429ebbdfc9f2d62d5bf41a4.jpg
#   inflating: root/ParlAI/emogen/train/images/a31a985a969a48467c6928d2db7edbe.jpg
#   inflating: root/ParlAI/emogen/train/images/edd95d8228b57ea4c220294312c1572b.jpg
#   inflating: root/ParlAI/emogen/train/images/6c6abe5f5397c2dc2cb9aca6a75f33.jpg
#   inflating: root/ParlAI/emogen/train/images/304ac35ae044c2dcb3b8713823962b3.jpg
#   inflating: root/ParlAI/emogen/train/images/891451e35b861f86efc841a1fe33bd.jpg
#   inflating: root/ParlAI/emogen/train/images/6361620a7f55e1a1327180318bba1.jpg
#   inflating: root/ParlAI/emogen/train/images/11f885719afa97152eaaa1e715a3a5.jpg
#   inflating: root/ParlAI/emogen/train/images/99ed5963b6cbc2b5ede4e39a65fce3d.jpg
#   inflating: root/ParlAI/emogen/train/images/5ca3745c99f962c785b13a44910d65.jpg
#   inflating: root/ParlAI/emogen/train/images/7dc75394ff847adfba72f2f47c36691d.jpg
#   inflating: root/ParlAI/emogen/train/images/8e5522719d7e223f15eadcec7dd57f.jpg
#   inflating: root/ParlAI/emogen/train/images/a3ba115d0b6db1161badbd7cf2eba99.jpg
#   inflating: root/ParlAI/emogen/train/images/551039707ff7768e67cbcbb1891180.jpg
#   inflating: root/ParlAI/emogen/train/images/9c9cbc69e07656e3eedd78f93fc7affd.jpg
#   inflating: root/ParlAI/emogen/train/images/5bf1911d3c2e3293d14ab259b2b826c.jpg
#   inflating: root/ParlAI/emogen/train/images/c49a1ffc471c4442aa82e835e746d81.jpg
#   inflating: root/ParlAI/emogen/train/images/f7d2bae55f42a4e75b50cbc153f171b2.jpg
#   inflating: root/ParlAI/emogen/train/images/27357c68d967f3ed5223b36b5eef710.jpg
#   inflating: root/ParlAI/emogen/train/images/bcd04f7d12b9c150336964241e876b1c.jpg
#   inflating: root/ParlAI/emogen/train/images/199e69e0845b3cc6c8aa49518a5833.jpg
#   inflating: root/ParlAI/emogen/train/images/24d615566f326fe69aa2c26a41e82f1.jpg
#   inflating: root/ParlAI/emogen/train/images/c4974cc6c478655e55e7f284f28e42cd.jpg
#   inflating: root/ParlAI/emogen/train/images/dc8dc958eb6548fda2820fdbc0345c.jpg
#   inflating: root/ParlAI/emogen/train/images/de9274a18d3269ba69bf44191711034.jpg
#   inflating: root/ParlAI/emogen/train/images/64dd905287cf2c38463ec082a160af4.jpg
#   inflating: root/ParlAI/emogen/train/images/1e2440425e137f9e39b4565696b6366.jpg
#   inflating: root/ParlAI/emogen/train/images/f39f8771ddea6a0573971af3459322.jpg
#   inflating: root/ParlAI/emogen/train/images/d67c72daa96f76b23b265ac854121d7.jpg
#   inflating: root/ParlAI/emogen/train/images/c9307333671f5e8c87f896f91ccbc8b.jpg
#   inflating: root/ParlAI/emogen/train/images/b1d8d2aab6655a3cf4531d25f6437ec.jpg
#   inflating: root/ParlAI/emogen/train/images/bd295f1423b818fb59648875ef16461.jpg
#   inflating: root/ParlAI/emogen/train/images/8f6851d0179dad257dbe0f859f7b31.jpg
#   inflating: root/ParlAI/emogen/train/images/c31c794e1edd1d17dad31e6856fb1ef.jpg
#   inflating: root/ParlAI/emogen/train/images/d2776538b80c2ec4376158d7847c17.jpg
#   inflating: root/ParlAI/emogen/train/images/3ad45c7e447dbf94e85611ade271745e.jpg
#   inflating: root/ParlAI/emogen/train/images/db3e86b33a33d44d2511378399e8016.jpg
#   inflating: root/ParlAI/emogen/train/images/1acde3ee60f150368ce67d2c44ebaa68.jpg
#   inflating: root/ParlAI/emogen/train/images/e78c3181bf7e879b1d3d851e982dc5.jpg
#   inflating: root/ParlAI/emogen/train/images/a7f772966da030e2bcbc277c5f54ea.jpg
#   inflating: root/ParlAI/emogen/train/images/581789c8a5d2390fae3b06dee364148.jpg
#   inflating: root/ParlAI/emogen/train/images/67e5eb144f89324498755682623fdf.jpg
#   inflating: root/ParlAI/emogen/train/images/b6a694d288c11cf233903ff1d66b.jpg
#   inflating: root/ParlAI/emogen/train/images/61662014a142541deb172a5986e8609f.jpg
#   inflating: root/ParlAI/emogen/train/images/c13bd281d0502378708ee0d354105281.jpg
#   inflating: root/ParlAI/emogen/train/images/b8adc7e8a279c5a036efbcb9498a.jpg
#   inflating: root/ParlAI/emogen/train/images/7c40d72d2d361dad22b32a2a1c2d5cb.jpg
#   inflating: root/ParlAI/emogen/train/images/7eb8ea39d8c537167d8775988f491a.jpg
#   inflating: root/ParlAI/emogen/train/images/2f391deaa3c323075fa9f9469a294.jpg
#   inflating: root/ParlAI/emogen/train/images/676a8ff0bcb6e14028cafe1b5ee6b8bc.jpg
#   inflating: root/ParlAI/emogen/train/images/73c52f466ebf5fbc090b98b826e9bf.jpg
#   inflating: root/ParlAI/emogen/train/images/962227557cb9e7d7dd8a4f27c97b2fe7.jpg
#   inflating: root/ParlAI/emogen/train/images/a3eaa28e42d7fa71c8ba519aa010fb9e.jpg
#   inflating: root/ParlAI/emogen/train/images/bd3e207029cf53a895c9ad23f83d2.jpg
#   inflating: root/ParlAI/emogen/train/images/cfe7246ba1d344c6a0ebccfe4cda36df.jpg
#   inflating: root/ParlAI/emogen/train/images/4d6698b8fa0582aea1bf3bc22356411.jpg
#   inflating: root/ParlAI/emogen/train/images/9d84fd4045d5a4b82ca21c48791ea57.jpg
#   inflating: root/ParlAI/emogen/train/images/9698287d79afcf72525f45cde7383a.jpg
#   inflating: root/ParlAI/emogen/train/images/27d0c94b61fc78fb15e55360d29eb5ef.jpg
#   inflating: root/ParlAI/emogen/train/images/f5ac905cac292e0ff17e20e112dc28.jpg
#   inflating: root/ParlAI/emogen/train/images/e8db90725e812f6ca72e3c54f0e3a44a.jpg
#   inflating: root/ParlAI/emogen/train/images/745b91cfc8bee7d9a7ab8a03c2c7884.jpg
#   inflating: root/ParlAI/emogen/train/images/27355fba6c1d962bd155e9b976afd93.jpg
#   inflating: root/ParlAI/emogen/train/images/1c4f0808bc93cecd99545ffb98827f8.jpg
#   inflating: root/ParlAI/emogen/train/images/df296db8c687723174738ade5b3ccdf6.jpg
#   inflating: root/ParlAI/emogen/train/images/3f88adcc61ebce74edc7b0fefd9fcd.jpg
#   inflating: root/ParlAI/emogen/train/images/2d3d90def3c56275f78acbe383abd31.jpg
#   inflating: root/ParlAI/emogen/train/images/6499cee9bc55aa7bfdf3e805118ef84.jpg
#   inflating: root/ParlAI/emogen/train/images/5366a3f2a83a85afb99cd4a682f365c.jpg
#   inflating: root/ParlAI/emogen/train/images/1c63dfe4b741df3bc941891a1e9707e.jpg
#   inflating: root/ParlAI/emogen/train/images/ffd73726de93e912bf46f8714f0dd37.jpg
#   inflating: root/ParlAI/emogen/train/images/abdf7becd0e478d3352dba21b58f19de.jpg
#   inflating: root/ParlAI/emogen/train/images/6a71f9fe65de257837234d78334cf.jpg
#   inflating: root/ParlAI/emogen/train/images/3228db5787d45ffe4c768f4962e73243.jpg
#   inflating: root/ParlAI/emogen/train/images/3ae1652c7c66abd84bfeb36349a54e3b.jpg
#   inflating: root/ParlAI/emogen/train/images/3c795db9bc44997ba262d7178b5ec2c.jpg
#   inflating: root/ParlAI/emogen/train/images/e8d5b6e2be76e1357c79fbfaf88be65.jpg
#   inflating: root/ParlAI/emogen/train/images/4ad27c1372fd85620b269242f5c1396.jpg
#   inflating: root/ParlAI/emogen/train/images/efe9561a4d42de49f9786b7fef716d80.jpg
#   inflating: root/ParlAI/emogen/train/images/1c4df6543d5a5040f9a8ba71567e8362.jpg
#   inflating: root/ParlAI/emogen/train/images/fe3edbd56e71286c3a85f21654db07c.jpg
#   inflating: root/ParlAI/emogen/train/images/3b9edfea963d0975f5c58079567a9.jpg
#   inflating: root/ParlAI/emogen/train/images/a22d974b243b096686262cbee1d2cb.jpg
#   inflating: root/ParlAI/emogen/train/images/27ab7f757b30b32e603444884e80abbe.jpg
#   inflating: root/ParlAI/emogen/train/images/54c3e39d0fcc1baa713bf2aa33b961c.jpg
#   inflating: root/ParlAI/emogen/train/images/91f07370f46169e08cd1869f5e425a5.jpg
#   inflating: root/ParlAI/emogen/train/images/88c2f3b2c7a224bd806d1babcc7791f1.jpg
#   inflating: root/ParlAI/emogen/train/images/8c3da090dcc8262bf1b13c4cd7968f84.jpg
#   inflating: root/ParlAI/emogen/train/images/e07da415d13161856bef67846c9dec.jpg
#   inflating: root/ParlAI/emogen/train/images/8a1cc673f6c9906838951a29a8fbede.jpg
#   inflating: root/ParlAI/emogen/train/images/73d014e554ec5013be2368b1ddd9277.jpg
#   inflating: root/ParlAI/emogen/train/images/9646c56edefbddfae9cb7d2c17f6b8d.jpg
#   inflating: root/ParlAI/emogen/train/images/46d1ff8288578f87a9c5f61aa233e2a.jpg
#   inflating: root/ParlAI/emogen/train/images/5c9f4773e8ef63bdf0ea873312cbfd7e.jpg
#   inflating: root/ParlAI/emogen/train/images/33ecfcb0aeaeb0b29efd8ca380da942.jpg
#   inflating: root/ParlAI/emogen/train/images/f60c9e88eab9fd94647811652752f50.jpg
#   inflating: root/ParlAI/emogen/train/images/ebb389030b3e2d2b49fb95f72a07bc4.jpg
#   inflating: root/ParlAI/emogen/train/images/d66dfc30b0db29fe5da70397aa5b53d.jpg
#   inflating: root/ParlAI/emogen/train/images/9813583721149d36e6e951c2d889f61c.jpg
#   inflating: root/ParlAI/emogen/train/images/1cfe1a338b99a675693881be65d185a.jpg
#   inflating: root/ParlAI/emogen/train/images/42301c58361f7d94360dc987a014ee.jpg
#   inflating: root/ParlAI/emogen/train/images/88c83ad390398a39f77b2cc4ab5dd30.jpg
#   inflating: root/ParlAI/emogen/train/images/bc8d060922d9e5c7ab468b4edd2795.jpg
#   inflating: root/ParlAI/emogen/train/images/bebdc1cd0b9ea87eb27fb4a0dd13d7.jpg
#   inflating: root/ParlAI/emogen/train/images/8ef4e45596b1467a34f7d63267791e4.jpg
#   inflating: root/ParlAI/emogen/train/images/6f2c5ed418a17630c246f7bfe2d5366d.jpg
#   inflating: root/ParlAI/emogen/train/images/57909a602b82219e7db72f1150f52fae.jpg
#   inflating: root/ParlAI/emogen/train/images/863d64ca71a9a8e621bd9d5d221d626.jpg
# ...
#   inflating: root/ParlAI/emogen/test/images/aafe22758a23f5ade17a1be0f692f484.jpg
#   inflating: root/ParlAI/emogen/test/images/cf58adb7b73ca4e341571792b7f674.jpg
#   inflating: root/ParlAI/emogen/test/images/d5e4fa8cabc327599d7563dba9d11d3.jpg
#   inflating: root/ParlAI/emogen/test/images/4b92b936a58e3b9590dad3dfd489b9a.jpg
#   inflating: root/ParlAI/emogen/test/images/cb61135e4ba77f57f698de1cbf253f7.jpg
#   inflating: root/ParlAI/emogen/test/images/6b3267557bc68d92251158d20fff2e0.jpg
#   inflating: root/ParlAI/emogen/test/images/33e03f63d744a9ca524e211071d4cf9.jpg
#   inflating: root/ParlAI/emogen/test/images/edbaaceb2d41fbcf2a7098a4b4b7c216.jpg
#   inflating: root/ParlAI/emogen/test/images/1edda17bc2ab9e309d4148bf25b1720.jpg
#   inflating: root/ParlAI/emogen/test/images/1bc51284b39394c7cf9da75e44ef79b.jpg
#   inflating: root/ParlAI/emogen/test/images/88a8c8c2c8129f542ac65476e5d47b.jpg
#   inflating: root/ParlAI/emogen/test/images/0c4ff62871a904274fd41cee695d85f.jpg
#   inflating: root/ParlAI/emogen/test/images/155bd447523811652b9ac2fcd747d52.jpg
#   inflating: root/ParlAI/emogen/test/images/d2bc7823d33ce051f5ef378d9e575.jpg
#   inflating: root/ParlAI/emogen/test/images/ae646045445345b56324ff11a89aad8c.jpg
#   inflating: root/ParlAI/emogen/test/images/af27769a9615fe3433bb138d29dadaee.jpg
#   inflating: root/ParlAI/emogen/test/images/2f6b3e90e675e3b80443e841d917015.jpg
#   inflating: root/ParlAI/emogen/test/images/1263e792b8f1b6befe9bdc07ed3e393.jpg
#   inflating: root/ParlAI/emogen/test/images/1b13974bbf387bbbf7bb96f6fc8cb3.jpg
#   inflating: root/ParlAI/emogen/test/images/64891152455d33cbee8586a2a7ec6b27.jpg
#   inflating: root/ParlAI/emogen/test/images/487d1722e553ddc8a332881ec27060c6.jpg
#   inflating: root/ParlAI/emogen/test/images/d279c446727e368829f8becb9f7af99.jpg
#   inflating: root/ParlAI/emogen/test/images/e8e3719d3d2aa9c54d2de5ddb59362c6.jpg
#   inflating: root/ParlAI/emogen/test/images/f51052cb9213dc3e33f2ccc23f4d572.jpg
#   inflating: root/ParlAI/emogen/test/images/d95eb7a1478c7bd0d53faff7baccf625.jpg
#   inflating: root/ParlAI/emogen/test/images/a1cc7c6dbfa1c8d3d6cc01cd4f25c2a.jpg
#   inflating: root/ParlAI/emogen/test/images/f2278f1ec961b734c3ef99e7aac6da4.jpg
#   inflating: root/ParlAI/emogen/test/images/187dbeb0d95c31cc7e0b2c11556888.jpg
#   inflating: root/ParlAI/emogen/test/images/b4f35930996e2244eb331d1e2a092a0.jpg
#   inflating: root/ParlAI/emogen/test/images/6cca87d25e4f58bec4db755f499ce65f.jpg
#   inflating: root/ParlAI/emogen/test/images/7a2cb9d8d55987530cddee0b2988.jpg
#   inflating: root/ParlAI/emogen/test/images/d29895f8c2bd5a2fdd1995aa2c0dc51.jpg
#   inflating: root/ParlAI/emogen/test/images/c56fdb7501a4b81faa0398850b3b343.jpg
#   inflating: root/ParlAI/emogen/test/images/6b8d9c2cb38179884c9b8486a3f6a21b.jpg
#   inflating: root/ParlAI/emogen/test/images/669483142ce32292558ab20f326a480.jpg
#   inflating: root/ParlAI/emogen/test/images/de4df8dd3b8cb9fa62aa65912845d86.jpg
#   inflating: root/ParlAI/emogen/test/images/5c7eea72690b3f64bbabc642ce46412.jpg
#   inflating: root/ParlAI/emogen/test/images/9d35e685368463c6167e3f7cc52d2f0.jpg
#   inflating: root/ParlAI/emogen/test/images/a4ea5c8a712d2d51d1ce1a059ba55ea.jpg
#   inflating: root/ParlAI/emogen/test/images/e095fd8ef65f5548f3db3e32a08ee993.jpg
#   inflating: root/ParlAI/emogen/test/images/f0b2b6f1f730d2e39fb4cb7cfc4acddd.jpg
#   inflating: root/ParlAI/emogen/test/images/a75d899b15cb3a6d07b87954360d5f0.jpg
#   inflating: root/ParlAI/emogen/test/images/3987a652fd80a47ce2d4a534c4a199.jpg
#   inflating: root/ParlAI/emogen/test/images/ebd4282f96cb5dc31342826f292e0da.jpg
#   inflating: root/ParlAI/emogen/test/images/2ea8dbcb19e860d0ea61eca228c179c2.jpg
#   inflating: root/ParlAI/emogen/test/images/c52e75c4975012fc8b74e2f05ea6dc49.jpg
#   inflating: root/ParlAI/emogen/test/images/59dedbaab29d6d3bfdceace42a2a1e9.jpg
#   inflating: root/ParlAI/emogen/test/images/57386eeaddceca278c6a6ea218daaf81.jpg
#   inflating: root/ParlAI/emogen/test/images/4339eeaf4b1d1ab51796e512c19af5.jpg
#   inflating: root/ParlAI/emogen/test/images/554fa354cadee9c22096aeb367d3fe8a.jpg
#   inflating: root/ParlAI/emogen/test/images/de1c54956453ed1ffa32b9fd254e236.jpg
#   inflating: root/ParlAI/emogen/test/images/4fe1f5164781c68c10924d179783c589.jpg
#   inflating: root/ParlAI/emogen/test/images/3368f651b8d6a4e37486f16352b6f77.jpg
#   inflating: root/ParlAI/emogen/test/images/be877e8b958869c6751578f137139d7c.jpg
#   inflating: root/ParlAI/emogen/test/images/22521460a860a3175e6b644a8c512e4.jpg
#   inflating: root/ParlAI/emogen/test/images/e3959b66ca922644caa4bd772ae882c.jpg
#   inflating: root/ParlAI/emogen/test/images/4d864d3c1c688ccce989197792b5c67.jpg
#   inflating: root/ParlAI/emogen/test/images/8031226c8d8579f8d6ae8d9e32f8efee.jpg
#   inflating: root/ParlAI/emogen/test/images/1cebeb55b513244d339fa654794842.jpg
#   inflating: root/ParlAI/emogen/test/images/a5a983373a206c719265e979c9969.jpg
#   inflating: root/ParlAI/emogen/test/images/d92dfb5224c67285c2d9d454dd8efeb.jpg
#   inflating: root/ParlAI/emogen/test/images/a09d16e399f5ffdc3c3b476b2faabd.jpg
#   inflating: root/ParlAI/emogen/test/images/9ac540a23a52689f3f2c579e18685a25.jpg
#   inflating: root/ParlAI/emogen/test/images/ce17d5e8b351b8e54b3927ccb351f2a2.jpg
#   inflating: root/ParlAI/emogen/test/images/5c284c412d98c581edd6e5dddf24f.jpg
#   inflating: root/ParlAI/emogen/test/images/bbb475ad0a638548104cc18e772676.jpg
#   inflating: root/ParlAI/emogen/test/images/e3ad8f3c6f5a2e634279a2a7e16d4080.jpg
#   inflating: root/ParlAI/emogen/test/images/5b237e3966d8f48cfb9b55f5352725b.jpg
#   inflating: root/ParlAI/emogen/test/images/7291efcfd35d6716b4bab8290318ef7.jpg
#   inflating: root/ParlAI/emogen/test/images/6d892ff1b2cb3c259b716eb1c5551534.jpg
#   inflating: root/ParlAI/emogen/test/images/a8765a96b06737adbd914a7f4d641ff5.jpg
#   inflating: root/ParlAI/emogen/test/images/eadc8fe351fafc72dff90f5f7f5843e.jpg
#   inflating: root/ParlAI/emogen/test/images/5d2b855163f3bedcf43c7c34dca654d.jpg
#   inflating: root/ParlAI/emogen/test/images/30987d1ab3fe1612c041899435a17.jpg
#   inflating: root/ParlAI/emogen/test/images/ba84ad46944937fe73cf8a84d17cce2.jpg
#   inflating: root/ParlAI/emogen/test/images/2288d04b30b0666f1bbf3966fea33a.jpg
#   inflating: root/ParlAI/emogen/test/images/3df5a72c1a58cd4bfd173a77ccc5ba.jpg
#   inflating: root/ParlAI/emogen/test/images/49dec265f750fd5662a53320d74c76.jpg
#   inflating: root/ParlAI/emogen/test/images/5db943a3154a91c6b3cf76dfd56604c.jpg
#   inflating: root/ParlAI/emogen/test/images/9c9af52e96e23ef23c79c2b27e5d95.jpg
#   inflating: root/ParlAI/emogen/test/images/2ff87a4534ea178140316ee656963e7.jpg
#   inflating: root/ParlAI/emogen/test/images/6e9fba4c9cbacf946765755efa068b6.jpg
#   inflating: root/ParlAI/emogen/test/images/bc3cf68a0df66d160cda55ab5ca6396.jpg
#   inflating: root/ParlAI/emogen/test/images/854a9d7b9b1f776b9d3372d7406ab02a.jpg
#   inflating: root/ParlAI/emogen/test/images/27d41b8e10ac3693cc8e2b6c2ca78e1b.jpg
#   inflating: root/ParlAI/emogen/test/images/42cbe06cadc99eddcbffdc9785977e41.jpg
#   inflating: root/ParlAI/emogen/test/images/82e1f461edb5652627b13e44995986d1.jpg
#   inflating: root/ParlAI/emogen/test/images/16b162d9c8f119c38cdf3896e15d2.jpg
#   inflating: root/ParlAI/emogen/test/images/46283e3150f49a91d0782941b5527780.jpg
#   inflating: root/ParlAI/emogen/test/images/bcbd5c2b6c48211725dc183883968855.jpg
#   inflating: root/ParlAI/emogen/test/images/255034df3feb1f437a758b48693545.jpg
#   inflating: root/ParlAI/emogen/test/images/2fc6209448a83eb0753b7c24a5d38f7.jpg
#   inflating: root/ParlAI/emogen/test/images/b6828723402c1b32fb3f9395669f1fdd.jpg
#   inflating: root/ParlAI/emogen/test/images/1926d51b9e024fb40f589866e2e36a.jpg
#   inflating: root/ParlAI/emogen/test/images/336a9648f5c2803b6da69d55f6528a4.jpg
#   inflating: root/ParlAI/emogen/test/images/3229bb3cd2971edda440f8ba5992bd51.jpg
#   inflating: root/ParlAI/emogen/test/images/daa40b749cb9bee7a05a9eefbf1f12.jpg
#   inflating: root/ParlAI/emogen/test/images/33eb444c3a198c699c3af5f575e13e9.jpg
#   inflating: root/ParlAI/emogen/test/images/ade8e5cdf4f79b7727405110c78d4771.jpg
#   inflating: root/ParlAI/emogen/test/images/257f7e1c0a033c5977ff139dddf.jpg
#   inflating: root/ParlAI/emogen/test/images/cb2b27e0eff3a86d8f1c324a438eca.jpg
#   inflating: root/ParlAI/emogen/test/images/549a54399e44571359b012484419fecb.jpg
#   inflating: root/ParlAI/emogen/test/images/fe922b636c8b8f69f5f9132373b2fad.jpg
#   inflating: root/ParlAI/emogen/test/images/519634b319832ece9f214147aaa3b66.jpg
#   inflating: root/ParlAI/emogen/test/images/f976b62c9e86ea78ed3454a8443df0c2.jpg
#   inflating: root/ParlAI/emogen/test/images/2651561beffa91c0fafebbac20c1473d.jpg
#   inflating: root/ParlAI/emogen/test/images/49e347d59c6c0da7a38855121eb5ffd.jpg
#   inflating: root/ParlAI/emogen/test/images/aae3679cb502fcc95d57ef09d378d5.jpg
#   inflating: root/ParlAI/emogen/test/images/27723c97720822840b5214a18c1b374.jpg
#   inflating: root/ParlAI/emogen/test/images/c267eb452b0a23ea4e7ab53c73d54b6.jpg
#   inflating: root/ParlAI/emogen/test/images/41595f1c4df62371f81ebb78da5d9458.jpg
#   inflating: root/ParlAI/emogen/test/images/84ce31722f3446db3a12a6fe60f298.jpg
#   inflating: root/ParlAI/emogen/test/images/a37a9b7882427e2d49446d5a1ab1a18.jpg
#   inflating: root/ParlAI/emogen/test/images/86a67f91678a95f6abe9a323116f3a2c.jpg
#   inflating: root/ParlAI/emogen/test/images/31b69a972fd4f8bbb3b7b3f26dc4a9bf.jpg
#   inflating: root/ParlAI/emogen/test/images/aac6f9918f36e436bd6a1934e5297b3.jpg
#   inflating: root/ParlAI/emogen/test/images/f9e2104479cff8597f29195991953b0.jpg
#   inflating: root/ParlAI/emogen/test/images/fc826b6646344d16cfc9fc33b5dc824b.jpg
#   inflating: root/ParlAI/emogen/test/images/4ff2bb84587519e9c8c99238d4e7314f.jpg
#   inflating: root/ParlAI/emogen/test/images/dcc4c99eb6f1bc3aba77f9aee89ce2.jpg
#   inflating: root/ParlAI/emogen/test/images/a0b357528f10afb5933c41286c61dc94.jpg
#   inflating: root/ParlAI/emogen/test/images/9c28ac7658cae29e926bedd4341ffd.jpg
#   inflating: root/ParlAI/emogen/test/images/69fca23ed437f21e973b27367826d41.jpg
#   inflating: root/ParlAI/emogen/test/images/e2b667cb3226c2c6a6f37acfb970178.jpg
#   inflating: root/ParlAI/emogen/test/images/dcea907e8ae7bfa7b3dd2e959c9375d0.jpg
#   inflating: root/ParlAI/emogen/test/images/460ffb231c36ba756d4e11e78cfbe51.jpg
#   inflating: root/ParlAI/emogen/test/images/2471bd2b19ea3b3fed2237d79c3b7be0.jpg
#   inflating: root/ParlAI/emogen/test/images/3fe619a2c85d46e2d0cb1b2ffe9a132a.jpg
#   inflating: root/ParlAI/emogen/test/images/29c7faaf8baf0fee617376e676c581.jpg
#   inflating: root/ParlAI/emogen/test/images/dd8574108dccb4f14d3b6d20c61b2a9a.jpg
#   inflating: root/ParlAI/emogen/test/images/6446d89be706ae77891702438be733c.jpg
#   inflating: root/ParlAI/emogen/test/images/b231f6798a6d91a93b633821616af62.jpg
#   inflating: root/ParlAI/emogen/test/images/7b626aaffdabc3ec5b38877d8364c.jpg
#   inflating: root/ParlAI/emogen/test/images/b4c7ae341252f039a96583c565d72ecb.jpg
#   inflating: root/ParlAI/emogen/test/images/c5d933ffbf4a7e1aad7cedc27eeea35.jpg
#   inflating: root/ParlAI/emogen/test/images/fb9e76dd62df4dcc94b894e874479ca.jpg
#   inflating: root/ParlAI/emogen/test/images/81891ae619bfad9da0d337bd9af542d7.jpg
#   inflating: root/ParlAI/emogen/test/images/279fbcb9e6b4d93f9ddef5d745415efb.jpg
#   inflating: root/ParlAI/emogen/test/images/9db7ade8429f44b3b9c174e26ad8692.jpg
#   inflating: root/ParlAI/emogen/test/images/545ef9b75526e7535dc38bf6abc5a0.jpg
#   inflating: root/ParlAI/emogen/test/images/2bc0cf2f5a31184ece896baa094de5.jpg
#   inflating: root/ParlAI/emogen/test/images/65dcd6cf474163ac877a42a43799b24.jpg
#   inflating: root/ParlAI/emogen/test/images/356bf1884a3e7105127e450a3ba4045.jpg
#   inflating: root/ParlAI/emogen/test/images/e48d7422fecbfddcd1b141130597c54.jpg
#   inflating: root/ParlAI/emogen/test/images/c8d35e3339bf4cb7f584fd48dd9f77aa.jpg
#   inflating: root/ParlAI/emogen/test/images/85ace3ce59a11f367a395dce7fe076.jpg
#   inflating: root/ParlAI/emogen/test/images/5e6e291b2cc324124c8a447a4d593da.jpg
#   inflating: root/ParlAI/emogen/test/images/bcf5a3af8ead89487aea4f91ff597514.jpg
#   inflating: root/ParlAI/emogen/test/images/ab6812b04e5486cb1517d8115a32d385.jpg
#   inflating: root/ParlAI/emogen/test/images/efb13d79edb06c2ffbf246d6137a9154.jpg
#   inflating: root/ParlAI/emogen/test/images/1c5c9d78ef04461b646f704431dc1f.jpg
#   inflating: root/ParlAI/emogen/test/images/b53018a5ac96e7d3ad813598fc790.jpg
#   inflating: root/ParlAI/emogen/test/images/5812273f465e38248af3383f97bd47.jpg
#   inflating: root/ParlAI/emogen/test/images/4d40cc6fc515bb6696eed9829ce034f4.jpg
#   inflating: root/ParlAI/emogen/test/images/60b9a6d1329be52550edb4a4b4336a.jpg
#   inflating: root/ParlAI/emogen/test/images/9aacbbd823e17cbf5a90a0fe4c73a875.jpg
#   inflating: root/ParlAI/emogen/test/images/b08fe58be1758bc31f6e2ea656c9b195.jpg
#   inflating: root/ParlAI/emogen/test/images/32614ef0931944957184d99cd26dba59.jpg
#   inflating: root/ParlAI/emogen/test/images/c4ed65a851bc2397b3ae4f7495b09af4.jpg
#   inflating: root/ParlAI/emogen/test/images/7180df73ed1c69b24e3817ca8eb06d2.jpg
#   inflating: root/ParlAI/emogen/test/images/5f197a445010e65a64abb958f41434a2.jpg
#   inflating: root/ParlAI/emogen/test/images/ea82f38b92c6efa318b835bc784b2d64.jpg
#   inflating: root/ParlAI/emogen/test/images/a8d5f8bd517a9cd3eff22e921483e651.jpg
#   inflating: root/ParlAI/emogen/test/images/9eb79266d3f1829916564238955fa1.jpg
#   inflating: root/ParlAI/emogen/test/images/8d2beb7f61b52f26a55f7c5c1184a3.jpg
#   inflating: root/ParlAI/emogen/test/images/924fcea8ef726a45f525ec77103a7bc2.jpg
#   inflating: root/ParlAI/emogen/test/images/1addd8dc659cb45cf7125a8a334b6e5.jpg
#   inflating: root/ParlAI/emogen/test/images/2a987fdc3d659488bb56d526f37ac28a.jpg
#   inflating: root/ParlAI/emogen/test/images/7d447c2d4f3c0b401c4d8a97d13a1.jpg
#   inflating: root/ParlAI/emogen/test/images/7feba4353c1ce51ed84e051bb27c9a.jpg
#   inflating: root/ParlAI/emogen/test/images/99449d2a6ea8f234f389ad58c6a7e5e1.jpg
#   inflating: root/ParlAI/emogen/test/images/88611e6c4635f9394e9ddbd7b173e72.jpg
#   inflating: root/ParlAI/emogen/test/images/e7b9b395ab96991923cd3205e244ca1.jpg
#   inflating: root/ParlAI/emogen/test/images/dbdbef6f9931643ddb6ac969a2b976.jpg
#   inflating: root/ParlAI/emogen/test/images/1b445d8036956cea9e6cede28435aa71.jpg
#   inflating: root/ParlAI/emogen/test/images/9bf6d14f43c542c1726ba365c3acc634.jpg
#   inflating: root/ParlAI/emogen/test/images/44d969c1fce990ac14dab5c741d8a4.jpg
#   inflating: root/ParlAI/emogen/test/images/2f1716e9195ed417ba66dd754ac9a8d6.jpg
#   inflating: root/ParlAI/emogen/test/images/a0369f5098e676fc9eede8a239592091.jpg
#   inflating: root/ParlAI/emogen/test/images/cadbd7180c21e98dab45582dd6ba0e3.jpg
#   inflating: root/ParlAI/emogen/test/images/359dcb4fddea7c7c468f837e68a3732.jpg
#   inflating: root/ParlAI/emogen/test/images/ea613d42f7203a6b49b664109174.jpg
#   inflating: root/ParlAI/emogen/test/images/7213148794ed9d88e751a9c1efabd95.jpg
#   inflating: root/ParlAI/emogen/test/images/fc74ae9e8d74f7b1495fafe146d6f.jpg
#   inflating: root/ParlAI/emogen/test/images/2e7dec245fd2f75ffb3236e58285cb78.jpg
#   inflating: root/ParlAI/emogen/test/images/815edbdfb1b5b587e088bdb3b35c616a.jpg
#   inflating: root/ParlAI/emogen/test/images/39f9eb13d935dc13e6f1b8d07376fa.jpg
#   inflating: root/ParlAI/emogen/test/images/6a7ee8da2d317d3587356f482a8e9bc.jpg
#   inflating: root/ParlAI/emogen/test/images/a6a8a7ef91f1d491d2eec9a4329957.jpg
#   inflating: root/ParlAI/emogen/test/images/6a6865a4d640b9b7eb76dfe8d46d9d.jpg
#   inflating: root/ParlAI/emogen/test/images/e172485d5c4cb20746b8cf76b581a2.jpg
#   inflating: root/ParlAI/emogen/test/images/a7d463e8aea2abd1c757b04f10c8d5.jpg
#   inflating: root/ParlAI/emogen/test/images/398de186403193430819d42c9582c59.jpg
#    creating: root/ParlAI/emogen/test/caption/
#   inflating: root/ParlAI/emogen/test/caption/test_caption.csv

# %%
import pandas as pd
import os
images_list=os.listdir('/content/drive/MyDrive/685/Project/root/ParlAI/emogen/test/images')
mapping_csv = pd.read_csv('/content/drive/MyDrive/685/Project/root/ParlAI/emogen/test/caption/test_caption.csv')
#mapping_csv.set_index('Sno',inplace=True)
count=0
rem_count=0
for i,row in mapping_csv.iterrows():
  count+=1
  if str(row['image_hash']+'.jpg') not in images_list:
    #print(row)
    print(i)
    mapping_csv.drop(mapping_csv.index[mapping_csv['image_hash'] == row['image_hash']],inplace=True)
    
    rem_count+=1

print(mapping_csv)
print(count,rem_count)
mapping_csv.reset_index(drop=True)
mapping_csv.to_csv('/content/drive/MyDrive/685/Project/root/ParlAI/emogen/test/caption/test.csv')
# Out:
#      Unnamed: 0  ...                        image_hash
# 0             0  ...  be877e8b958869c6751578f137139d7c
# 1             1  ...  43998d5eee707c76ae879c3bf733764b
# 2             2  ...  4b4d5bce7238f027615e497fd86ca5b3
# 3             3  ...   ebd4282f96cb5dc31342826f292e0da
# 4             4  ...  ce17d5e8b351b8e54b3927ccb351f2a2
# ..          ...  ...                               ...
# 471         471  ...    187dbeb0d95c31cc7e0b2c11556888
# 472         472  ...  637a5ecb1a8ad062e5bd9366b8d7fbde
# 473         473  ...   b9eeda9ec527bf93a1a38b632fc9f97
# 474         474  ...   c5249fbf2dc5ce47d3b2224f8c8855b
# 475         475  ...  fc826b6646344d16cfc9fc33b5dc824b
#
# [476 rows x 7 columns]
# 476 0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install transformers
import os
import torch
import random
import warnings
import numpy as np
import transformers
import pandas as pd 
from PIL import Image
import torch.nn as nn
warnings.filterwarnings("ignore")
import torchvision.transforms as T
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from typing import Callable, Optional


## For Reproducibility
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
seed_everything(42)

## Tokenizer
tokenizer = transformers.BertTokenizer.from_pretrained("bert-base-uncased",do_lower_case=True)

## Device Configuration 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Collecting transformers
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 8.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 56.1 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 51.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 57.5 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 632 kB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.5
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
def load_data(data_path,data_type):
  csv_str =str("caption/"+data_type+"_"+"caption.csv")
  img_path = os.path.join(data_path,data_type,'images/')
  mapping_csv = pd.read_csv(os.path.join(data_path,data_type,csv_str))
  print(len(mapping_csv.index))
  image_name = {
    'image_name':img_path+mapping_csv['image_hash']+'.jpg'
  }
  
  captions = {
      'caption':mapping_csv['comment']
  }
  image_name_df = pd.DataFrame.from_dict(image_name)
  captions_df = pd.DataFrame.from_dict(captions)
  if data_type!="train":
    candidates = {
        'candidates':mapping_csv['candidates']
    }
    candidates_df = pd.DataFrame.from_dict(candidates)
    df = pd.concat([image_name_df,captions_df,candidates_df], axis=1)
  else:
    df = pd.concat([image_name_df,captions_df], axis=1)
  #Image.open(df['image_name'][0]) To debug if Image path is correct
  return df

# %%
data_dir = '/content/drive/MyDrive/685/Project/root/ParlAI/emogen'
train=load_data(data_dir,"train")
val=load_data(data_dir,"val")
test = load_data(data_dir,"test")
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# 8675
# 216
# 476
# (8675, 2)
# (216, 3)
# (476, 3)

# %%
class DatasetPrep(Dataset):
    
    def __init__(self, df, 
                 transforms: Optional[Callable] = None,name=None) -> None:
        self.df = df
        self.name=name
        self.transforms = T.Compose([
            T.ToTensor(),
            T.Normalize(mean = [0.5], std = [0.5]),
            T.Resize((256,256)),
        ])
        
    def __len__(self) -> int:
        return len(self.df)
    
    def __getitem__(self, idx: int):
        
        image_id = self.df.image_name.values[idx]
        image = Image.open(image_id).convert('RGB')
            
        if self.transforms is not None:
            image = self.transforms(image)
            
        comments = self.df[self.df.image_name == image_id].values.tolist()[0][1:][0]
        encoded_inputs = tokenizer(comments,
                                   return_token_type_ids = False, 
                                   return_attention_mask = False, 
                                   max_length = 100, 
                                   padding = "max_length",
                                  return_tensors = "pt")
        
        sample = {"image":image.to(device),"captions": encoded_inputs["input_ids"].flatten().to(device)}
        if self.name!="train":
          candidates=self.df[self.df.image_name == image_id].values.tolist()[0][1:][1:]
          print(candidates)
          encoded_cand = tokenizer(candidates,
                                   return_token_type_ids = False, 
                                   return_attention_mask = False, 
                                   max_length = 100, 
                                   padding = "max_length")
          sample["candidates"] = encoded_cand["input_ids"]
          #print(sample["candidates"])
          
        

        return sample

# %%
batch_size = 4

train_dataset = DatasetPrep(train, transforms = True,name="train")

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, drop_last=True)

val_dataset = DatasetPrep(val, transforms = True,name="val")
#print(val_dataset.__getitem__(2))
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size = batch_size,drop_last=True)

test_dataset = DatasetPrep(test, transforms = True,name="test")
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size,drop_last=True)

# %%
class CNN(nn.Module):
    
    def __init__(self, embed_size):
        super(CNN, self).__init__()
        model = models.resnet50(pretrained=True)
        for param in model.parameters():
            param.requires_grad_(False)
        
        modules = list(model.children())[:-1]
        self.model = nn.Sequential(*modules)
        self.embed = nn.Linear(model.fc.in_features, embed_size)
        
    def forward(self, image):
        features = self.model(image)
        features = features.view(features.size(0), -1)
        features = self.embed(features)
                
        return features

# %%
class RNN(nn.Module):
    
    def __init__(self, input_size, hidden_size, embedding_dim,vocab_size):
        super(RNN, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_dim = embedding_dim
        self.vocab_size = vocab_size
        
        self.embedding = nn.Embedding(num_embeddings = vocab_size,embedding_dim = embedding_dim)
        
        self.lstm = nn.LSTM(input_size=input_size,
                            hidden_size=hidden_size,
                            batch_first=True)
        
        self.fc = nn.Linear(hidden_size, vocab_size)
        
    def init_hidden(self, features):
        
        return (torch.autograd.Variable(torch.zeros(1,4,512).to(device)), 
                torch.autograd.Variable(features.unsqueeze(0)).to(device))
        
    def forward(self, features, captions):
        
        state = self.init_hidden(features)
        
        embed = self.embedding(captions)
                    
        lstm_out, state = self.lstm(embed, state)
                        
        outputs = self.fc(lstm_out)
        outputs = outputs.view(-1, self.vocab_size)
        
        return outputs

# %%
example_batch = next(iter(train_dataloader))

image, captions = example_batch["image"], example_batch["captions"]

encoder = CNN(embed_size = 512).to(device)
decoder = RNN(input_size = 512, hidden_size = 512, embedding_dim=512, vocab_size = 28881).to(device)

features = encoder(image)
embed = decoder(features, captions)

print("Image Transformation: ", image.shape, " --> ", features.shape)
print("Captions Transformation: ", captions.shape, " --> ", embed.shape)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Image Transformation:  torch.Size([4, 3, 256, 256])  -->  torch.Size([4, 512])
# Captions Transformation:  torch.Size([4, 100])  -->  torch.Size([400, 28881])

# %%
vocab_size = 90000
steps_per_epoch = 19069 // 4

encoder = CNN(embed_size = 512).to(device)
decoder = RNN(input_size = 512, hidden_size = 512, embedding_dim=512, vocab_size = vocab_size).to(device)

criterion = nn.CrossEntropyLoss().to(device)
params = list(decoder.parameters()) + list(encoder.embed.parameters())

optimizer = torch.optim.Adam(params, lr=0.001)

# %%
def accuracy(scores, targets, k):
    """
    Computes top-k accuracy, from predicted and true labels.
    :param scores: scores from the model
    :param targets: true labels
    :param k: k in top-k accuracy
    :return: top-k accuracy
    """

    batch_size = targets.size(0)
    _, ind = scores.topk(k, 1, True, True)
    correct = ind.eq(targets.view(-1, 1).expand_as(ind))
    correct_total = correct.view(-1).float().sum()  # 0D tensor
    return correct_total.item() * (100.0 / batch_size)

# %%
def validate(val_loader,encoder,decoder,criterion):
  encoder.eval()
  decoder.eval()
  for idx, sample in enumerate(train_dataloader):
    image, captions,candidates = torch.tensor(sample['image']).to(device), torch.tensor(sample['captions']).to(device),torch.tensor(sample['candidates']).to(device)
    features = encoder(image)
    outputs = decoder(features, captions)
    loss = criterion(scores, targets)
    print(len(candidates))
    _, preds = torch.max(scores_copy, dim=2)
    preds = preds.tolist()
    hypotheses.extend(preds)

    assert len(references) == len(hypotheses)

    # Calculate BLEU-4 scores
    bleu4 = corpus_bleu(references, hypotheses)

    return bleu4

# %%
for epoch in range(10):
    print("Epoch ",epoch)

    for idx, sample in enumerate(train_dataloader):
        
        if idx > steps_per_epoch:
            break
        
        image, captions = torch.tensor(sample['image']).to(device), torch.tensor(sample['captions']).to(device)
        
        # zero the parameter gradients
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Forward pass
        features = encoder(image)
        outputs = decoder(features, captions)

        
        # Compute the Loss
        loss = criterion(outputs.view(-1, vocab_size), 
                         captions.view(-1))
        #acc = accuracy(outputs,captions.view(-1),5)
        
        # Backward pass.
        loss.backward()

        
        # Update the parameters in the optimizer.
        optimizer.step()
        state = {'epoch': epoch,
             'encoder': encoder,
             'decoder': decoder,
             'optimizer': optimizer}
        filename = 'checkpoint_' + '.pth.tar'
    print(str("loss"+str(loss)))
    torch.save(state, filename)
# Out:
# Epoch  0
# losstensor(0.1242, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  1
# losstensor(0.0182, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  2
# losstensor(0.0001, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  3
# losstensor(4.0698e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  4
# losstensor(1.7353e-05, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  5
# losstensor(7.0488e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  6
# losstensor(2.6161e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  7
# losstensor(1.0013e-06, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  8
# losstensor(4.2647e-07, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epoch  9
# losstensor(2.1487e-07, device='cuda:0', grad_fn=<NllLossBackward0>)
