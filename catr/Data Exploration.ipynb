# %%
import pandas as pd
import json
pd.set_option('display.max_rows', None)

# %%
file = open('train.json')
data_json = json.load(file)
data = pd.DataFrame.from_dict(data_json).reset_index(drop=True)

# %%
data['personality'].value_counts()
# Out:
# Honest                                       895
# Stupid                                       893
# Perceptive                                   891
# Rigid                                        891
# Attractive                                   889
# Fun-loving                                   889
# Impersonal                                   888
# Gloomy                                       887
# Pretentious (Snobbish, Showy)                886
# Irritable                                    885
# Fickle (Changeable, Temperamental)           885
# Mellow (Soothing, Sweet)                     884
# Rustic (Rural)                               884
# Childish                                     884
# Monstrous                                    883
# Quirky                                       883
# Objective (Detached, Impartial)              881
# Fawning (Flattering, Deferential)            881
# Amusing                                      881
# ...

# %%
data[data['personality']=='Sarcastic']['personality'].value_counts()
# Out:
# Sarcastic    879
# Name: personality, dtype: int64

# %%
data[data['personality']=='Sarcastic']
# Out:
#        personality                                            comment  \
# 5        Sarcastic                               Yes please sit by me
# 149      Sarcastic                 I couldn't imagine a prettier car.
# 517      Sarcastic              Park your boat somewhere else, buddy.
# 1169     Sarcastic                          wow this one busy street
# 1285     Sarcastic  Oh yeah, it's such a long way to the door that...
# 1286     Sarcastic  I bet the architect of that building doesn't k...
# 1850     Sarcastic  Oh I just love the beach. The humid heat and d...
# 2259     Sarcastic             Lets layer the sky some more with smog
# 3649     Sarcastic  I'M TRYING TO IMAGINE A MORE BORING PIECE OF C...
# 3716     Sarcastic  That guy in the blue was just kidding with you...
# 3905     Sarcastic                 Wow, you look so happy to be there
# 3995     Sarcastic        Catching scrawny fish in the smelly harbor.
# ...

# %%
data[data['personality']=='Witty']
# Out:
#        personality                                            comment  \
# 24           Witty             This would make a good skeeball game.
# 121          Witty  You don't have to solve the sphinx's riddle to...
# 496          Witty             THE WATER RUNS BU THE TREE HOLDETH ICE
# 992          Witty  Here we see the rare Schoolbus Bird, so named ...
# 1223         Witty                   Only red and yellow in this one?
# 1426         Witty  The gloomy weather in this picture is eerie bu...
# 1747         Witty                          I had an amusing vacation
# 1893         Witty                       If only that car could talk!
# 1999         Witty                 Weddings truly are a family affair
# 2068         Witty           Beauty and this picture go hand in hand
# 2097         Witty  Small crowd today huh? Sunday football must be...
# 2121         Witty  I bet that rope wrapped in the middle is the o...
# ...
