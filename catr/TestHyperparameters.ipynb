# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/CollabProjects/685/catr"
os.chdir(path)
print(os.getcwd())
# !nvidia-smi
# Out:
# /content/drive/MyDrive/CollabProjects/685/catr
# Thu Dec 16 09:36:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 8.2 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 50.7 MB/s
# ...
#      |████████████████████████████████| 61 kB 500 kB/s
# ...
#      |████████████████████████████████| 895 kB 48.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 57.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import torch
from finetune import finetune
from configuration import Config
config = Config()

# %%
batch_sizes = [16,32]
lrs = [1e-5, 2e-5, 5e-5]
lr_drops = [10,15,20]
config.checkpoint = './checkpoint_1.pth'
config.epochs = 5
config.lr = 5e-5
config.lr_drop = 10
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_2.pth'
config.epochs = 7
config.lr = 2e-5
config.lr_drop = 10
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_3.pth'
config.epochs = 7
config.lr = 5e-5
config.lr_drop = 15
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a6723752788> in <module>()
# ----> 1 config.checkpoint = './checkpoint_3.pth'
#       2 config.epochs = 7
#       3 config.lr = 5e-5
#       4 config.lr_drop = 15
#       5 config.batch_size = 8
#
# NameError: name 'config' is not defined

# %%
config.checkpoint = './checkpoint_4.pth'
config.epochs = 10
config.lr = 5e-5
config.lr_drop = 15
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_5.pth'
config.epochs = 30
config.lr = 5e-5
config.lr_drop = 15
config.batch_size = 16
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_6.pth'
config.epochs = 10
config.lr = 2e-4
config.lr_drop = 15
config.batch_size = 16
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Number of params: 83959866
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Train: 8674
# Valid: 216
# Start Training..
# Epoch: 0
# ...

# %%
config.checkpoint = './checkpoint_sarcasm_1.pth'
config.epochs = 10
config.lr = 5e-5
config.lr_drop = 10
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Number of params: 83959866
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Train: 1743
# Valid: 50
# Start Training..
# Epoch: 0
# ...

# %%
config.checkpoint = './checkpoint_sarcasm_3.pth'
config.epochs = 10
config.lr = 1e-5
config.lr_drop = 10
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_sarcasm_back_trans.pth'
config.epochs = 15
config.lr = 2e-5
config.lr_drop = 10
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_sarcasm_back_trans_2.pth'
config.epochs = 15
config.lr = 5e-5
config.lr_drop = 10
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_sarcasm_augmented_1.pth'
config.epochs = 15
config.lr = 5e-5
config.lr_drop = 10
config.batch_size = 16
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
config.checkpoint = './checkpoint_sarcasm_augmented_1_2.pth'
config.epochs = 10
config.lr = 2e-5
config.lr_drop = 10
config.batch_size = 8
training_losses, validation_losses = finetune(config)
# Out:
# Initializing Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Downloading: "https://github.com/saahiluppal/catr/releases/download/0.2/weight493084032.pth" to /root/.cache/torch/hub/checkpoints/weight493084032.pth
#   0%|          | 0.00/322M [00:00<?, ?B/s]
# Number of params: 83959866
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...
